# %%
import requests
from bs4 import BeautifulSoup
myBaseUrl = "https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber="
# for different product change this base url, should end with page number = 
start_urls = []
for i in range(1, 19): # for different product change second number in range to number of review pages + 1
    start_urls.append(myBaseUrl + str(i))
print(start_urls)
HEADERS = {
    'authority': 'www.amazon.com',
'method' : 'GET',
'path' : '/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
response = []
for i in start_urls:
    response.append(requests.get(i,headers=HEADERS))
print(response)
# Out:
# ['https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1', 'https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2', 'https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3', 'https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4', 'https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5', 'https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-
# ...

# %%
soup = []
for i in response:
    soup.append(BeautifulSoup(i.content))
review = []
for i in soup:
    review.append(i.findAll("span",{'class':"a-size-base review-text review-text-content"}))
for i in review:
    for j in i:
        print(j.text)
# Out:
#   They turned out to be of a very high quality.  Large handles for my disabled husband to hold with and the flat part the cup sits on makes it very stable for him to sit down. The plastic is very clear and the lid fits on tight
#
#
#
#
#   I bought this for a lady at a nursing home. There are a lot of people at nursing homes that need cups like these. And the nursing home usually doesn't have an unlimited supply. So make sure to write the person's name on the bottom of the cup in a permanent marker because the cup might get stolen by another person living there who can't always get a cup from the kitchen, or it may accidentally be picked up by the staff and taken to the kitchen where it then will very likely disappear. Be careful, keep an eye on it, write their name on it.It's a great cup.
#
#
#
#
# ...

# %%
titles = []
for soupnum in soup:
    title = soupnum.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"})
    for i in title:
        print(i.text)
# Out:
# They turned out to be of a very high quality ...
#
#
# Great product, be careful at nursing homes
#
#
# 2-handled cup
#
#
# Best cup for my disabled father
#
#
# Great Product
#
#
# Don't waste your money.
#
#
# Microwavable lightweight double handle
#
#
# Great for an elderly!!!
#
#
# For mom in nursing home
#
#
# My elderly mother loves this cup. I do too.
#
#
# awesome
#
#
# No more nighttime spills!
#
#
# NOT SPILL PROOF
#
#
# Great help for people with Alzheimer’s
#
#
# No more spills yay!
#
#
# Disappointed
#
#
# Not spillproof
#
#
# Light and durable
#
#
# Great Product!
#
#
# Great for elderly with joint or muscle weakness.
#
#
# It’s a sippy cup. No two ways about it.
#
#
# Don't buy
#
#
# Excellent Product. Mom loves it
#
#
# lid snaps on
#
#
# Just okay
#
#
# not great for seniors
#
#
# It gave my husband the independence he so need
#
#
# Convenient mug
#
#
# Perfect Cup
#
#
# Five Stars
#
#
# Reason for buying
#
#
# You get what you pay for.
#
#
# ...

# %%
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
HEADERS = {
    'authority': 'www.amazon.com',
'method' : 'GET',
'path' : '/Special-Supplies-Independence-Lightweight-Spill-Resistant/product-reviews/B077739BGX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
 
    # The webpage URL
URL = "https://www.amazon.com/Special-Supplies-Independence-Lightweight-Spill-Resistant/dp/B077739BGX/"
 
    # HTTP Request
webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
soup = BeautifulSoup(webpage.content, "lxml")
print("Product Rating =", get_rating(soup))
print("Number of Product Reviews =", get_review_count(soup))
# Out:
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 595 ratings
