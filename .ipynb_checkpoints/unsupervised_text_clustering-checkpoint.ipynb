# %%
import facebook
import numpy as np
import pandas as pd

# %%
token = "EAAmthfHoDm4BAEJMZAlwGYjffTkOvz5jjqTOZCdix1CA4N9b5M1OyMh2hhgzPX6uMwPK9fD70tHCt0ZADUS8MsXKTrNnnjYZCF6RYFv0Ta42AXvoqmP9pxGxICVq2KxjZCFwwCRysiesCWtJZAQGfe0ViXFIm6zs0lLNKURfxdBGwGq3FwDmpc2lVJeySo6FnOxJxn8JXpPwZDZD"
graph = facebook.GraphAPI(access_token=token, 
                              version="2.12")

# %%
group = graph.get_object(id='Kawaiilord', fields='description')
# Out:
# ---------------------------------------------------------------------------
# GraphAPIError                             Traceback (most recent call last)
# <ipython-input-47-520860a458c6> in <module>
# ----> 1 group = graph.get_object(id='Kawaiilord', fields='description')
#
# /usr/local/lib/python3.7/site-packages/facebook/__init__.py in get_object(self, id, **args)
#     124     def get_object(self, id, **args):
#     125         """Fetches the given object from the graph."""
# --> 126         return self.request("{0}/{1}".format(self.version, id), args)
#     127
#     128     def get_objects(self, ids, **args):
#
# /usr/local/lib/python3.7/site-packages/facebook/__init__.py in request(self, path, args, post_args, files, method)
#     311
#     312         if result and isinstance(result, dict) and result.get("error"):
# --> 313             raise GraphAPIError(result)
#     314         return result
#     315
#
# ...

# %%
group
# Out:
# {'description': 'Anything and everything dysphagia research related! We meet monthly virtually over zoom to discuss a selected swallowing research article.\n\nThis is a comfortable, open environment to discuss and ask questions related to the latest dysphagia research. When posting articles or tools you think will be helpful to other clinicians, make sure to do so appropriately. Any copyrighted materials will be removed from the posting. \n\nThanks for being here! Let’s get down to business!',
#  'id': '1550158295165812'}

# %%
posts = graph.get_connections(id='1550158295165812',connection_name='feed')
# Out:
# ---------------------------------------------------------------------------
# GraphAPIError                             Traceback (most recent call last)
# <ipython-input-35-aa8af3000208> in <module>
# ----> 1 posts = graph.get_connections(id='1550158295165812',connection_name='feed')
#
# /usr/local/lib/python3.7/site-packages/facebook/__init__.py in get_connections(self, id, connection_name, **args)
#     148         """Fetches the connections for given object."""
#     149         return self.request(
# --> 150             "{0}/{1}/{2}".format(self.version, id, connection_name), args
#     151         )
#     152
#
# /usr/local/lib/python3.7/site-packages/facebook/__init__.py in request(self, path, args, post_args, files, method)
#     311
#     312         if result and isinstance(result, dict) and result.get("error"):
# --> 313             raise GraphAPIError(result)
#     314         return result
#     315
#
# ...

# %%
from facebook_scraper import get_posts

# %%
for post in get_posts(group='548950768613889',pages=1):
    post

# %%
from facepy import GraphAPI
import json

# %%
graph = GraphAPI("EAAmthfHoDm4BAEJMZAlwGYjffTkOvz5jjqTOZCdix1CA4N9b5M1OyMh2hhgzPX6uMwPK9fD70tHCt0ZADUS8MsXKTrNnnjYZCF6RYFv0Ta42AXvoqmP9pxGxICVq2KxjZCFwwCRysiesCWtJZAQGfe0ViXFIm6zs0lLNKURfxdBGwGq3FwDmpc2lVJeySo6FnOxJxn8JXpPwZDZD")

# %%
group_id = "548950768613889"

# %%
data = graph.get(group_id+'/feed',page=False,limit=100,since="2020-01-01",until="2020-01-15")
# Out:
# Exception on https://graph.facebook.com/548950768613889/feed: [200] (#200) Requires either admin with granted managed_group pemissions or member
#       using installed app., retries remaining: 3
# Exception on https://graph.facebook.com/548950768613889/feed: [200] (#200) Requires either admin with granted managed_group pemissions or member
#       using installed app., retries remaining: 2
# Exception on https://graph.facebook.com/548950768613889/feed: [200] (#200) Requires either admin with granted managed_group pemissions or member
#       using installed app., retries remaining: 1
# Exception on https://graph.facebook.com/548950768613889/feed: [200] (#200) Requires either admin with granted managed_group pemissions or member
#       using installed app., retries remaining: 0
# ---------------------------------------------------------------------------
# OAuthError                                Traceback (most recent call last)
# <ipython-input-43-f4bd1e316db8> in <module>
# ...

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://www.amazon.com/Bionix-Safestraw-Drinking-Thickened-Liquids/product-reviews/B00L3D2MY0/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1'
request_cookies={'session-id':'130-7918883-5154039',
                 'session-id-time': '2082787201l', 
                 'ubid-main':'135-6290692-3295602',
                 'i18n-prefs': 'USD',
                 'session-token':''
                }

# %%
requests.get(url,cookies=request_cookies)
# Out:
# <Response [503]>

# %%
request_headers={'authority': 'images-na.ssl-images-amazon.com',
                    'method': 'GET',
                    'path': '/images/I/41Ft9AfhQ+L._RC%7C31fOrM4U5KL.js,11PLCo6zxLL.js,21kzbzVTvjL.js,41Ul1U+eUaL.js,31yCl0u2BnL.js,61W4tlTmRbL.js,41l6Ts6x3oL.js_.js?AUIClients/DesktopRemoteARPMetaAsset',
                    'scheme': 'https',
                    'accept': '*/*',
                    'sec-ch-ua': '"Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"',
                    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36'
                }

# %%
response = requests.get(url,headers=request_headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
review = soup.findAll("span",{'class':"a-size-base review-text review-text-content"})

# %%
for i in review:
    print(i.text)
# Out:
#   Really good for me, with difficulty swallowing. No problem with it at all, for me it is great for Atypicle Parkinson’s: PSP
#
#
#
#
#   It doesn’t work for me I have no suction my throat is the problem
#
#
#
#
#   They don’t last too long
#
#
#
#
#   It helped my sister drink water again after having a massive stroke.
#
#
#
#
#   Difficult to use.
#
#
#
#
#   This did not work for my Mom who had a stroke.  The weight at the bottom kept getting stuck.  Straw didn't seat well.  Waste of money.
#
#
#
#
#   My student with autism often chickens when drinking. This has kept her from choking al together. It’s awesome! Worth the money for sure.
#
#
#
#
#   Size not the size I expected, but the product is pretty good l.
#
#
#
#
# ...

# %%
request_headers={'authority': 'static.xx.fbcdn.net',
                    'method': 'GET',
                    'path': '/rsrc.php/v3i2DN4/y1/l/en_US/_nM0byYhZBah093938F9eG.js?_nc_x=X5XB-rM9dW-',
                    'scheme': 'https',
                    'accept': '*/*',
                    'sec-ch-ua': '"Chromium";v="88", "Google Chrome";v="88", ";Not A Brand";v="99"',
                    'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36'
                }

# %%
url='https://www.facebook.com/groups/548950768613889'

# %%
response = requests.get(url,headers=request_headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.findAll("div",{'class': "kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x c1et5uql ii04i59q"})
# Out:
# []

# %%
soup.title
# Out:
# <title>Facebook</title>

# %%
soup.get_text()
# Out:
# 'Facebook\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'
