# %%
import pandas as pd
import numpy.matlib as np
import os

# %%
rootdir = 'c:\\Users\leey2\Amazon_Reviews'
all_reviews = []

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        df = pd.read_csv(os.path.join(subdir,file))
        df["Product"] = np.repmat(file,df.shape[0],1)
        all_reviews.append(df)
        print(df.head())
all_reviews_df = pd.concat(all_reviews)
# Out:
#                                       title  \
# 0               It is great for me overall!
# 1               Easy straws for the elderly
# 2                              4-5 time use
# 3  You have to push the straw in very hard!
# 4                          Difficult to use
#
#                                               review                star  \
# 0  Really good for me, with difficulty swallowing...  5.0 out of 5 stars
# 1  It doesn’t work for me I have no suction my th...  1.0 out of 5 stars
# 2                           They don’t last too long  3.0 out of 5 stars
# 3  It helped my sister drink water again after ha...  5.0 out of 5 stars
# 4                                  Difficult to use.  2.0 out of 5 stars
#
#                Product
# 0  soupbionixthick.csv
# 1  soupbionixthick.csv
# 2  soupbionixthick.csv
# 3  soupbionixthick.csv
# 4  soupbionixthick.csv
#                                                title  \
# 0                   Mostly retired rehab nurse here.
# 1  Frustration for memory patients discourages th...
# 2                     Doesn’t do the job as expected
# 3                                Bellow expectations
# 4                                  Excellent product
#
#                                               review                star  \
# 0  It's a good tool for someone cognitively intac...  4.0 out of 5 stars
# 1  Recommended by Speech therapist:The package ca...  2.0 out of 5 stars
# 2  This device was recommended by a speech therap...  1.0 out of 5 stars
# 3  is difficult to be the first negative reviewer...  1.0 out of 5 stars
# 4  Item worked beyond expectations. My aunt can n...  5.0 out of 5 stars
#
#               Product
# 0  soupbionixthin.csv
# 1  soupbionixthin.csv
# 2  soupbionixthin.csv
# 3  soupbionixthin.csv
# 4  soupbionixthin.csv
#                                                title  \
# 0                            Don't waste your money!
# 1  It is a great idea, and I was hopeful that thi...
# 2           Works but not for all. Mfg unresponsive.
# 3                                          Wedge cup
# 4                                       Works great!
#
#                                               review                star  \
# 0  I was looking for a device to control the amou...  1.0 out of 5 stars
# 1  I work as a speech-language pathologist with a...  1.0 out of 5 stars
# 2  Bought for my wife who has a motor disease, wh...  3.0 out of 5 stars
# 3                                 Worked as intended  4.0 out of 5 stars
# 4  Very Pricey, but can't find anything that work...  5.0 out of 5 stars
#
#             Product
# 0  soupikinsman.csv
# 1  soupikinsman.csv
# 2  soupikinsman.csv
# 3  soupikinsman.csv
# 4  soupikinsman.csv
#                                                title  \
# 0  Great for people who cannot, for whatever reas...
# 1  She has very bad arthritis throughout her body...
# 2                                  Excellent producr
# 3                         Great Cup for Older Adults
# 4               Excellent solution for hand tremors.
#
#                                               review                star  \
# 0  My bedridden husband can still drink from cups...  5.0 out of 5 stars
# 1  I bought this for my mother to try to heat up ...  5.0 out of 5 stars
# 2  My mom with dementia had a stroke and was havi...  5.0 out of 5 stars
# 3  We purchased this set of cups for my 87 year o...  5.0 out of 5 stars
# 4  This works very well for people with hand trem...  5.0 out of 5 stars
#
#                        Product
# 0  soupindependenceplastic.csv
# 1  soupindependenceplastic.csv
# 2  soupindependenceplastic.csv
# 3  soupindependenceplastic.csv
# 4  soupindependenceplastic.csv
#                                title  \
# 0     Helped make it safer to drink.
# 1                Works as advertised
# 2                           Leaks!!!
# 3  Holds only a few ounces of liquid
# 4                      Life changer!
#
#                                               review                star  \
# 0  We had to help my Aunt drink all liquids with ...  5.0 out of 5 stars
# 1  Wife has dysphagia problems and this device me...  5.0 out of 5 stars
# 2  This cup has a small hole on the bottom and it...  1.0 out of 5 stars
# 3  This is only good for someone in terrible cond...  1.0 out of 5 stars
# 4  It works wonderfully for my granddaughter who ...  5.0 out of 5 stars
#
#          Product
# 0  soupirije.csv
# 1  soupirije.csv
# 2  soupirije.csv
# 3  soupirije.csv
# 4  soupirije.csv
#                                                title  \
# 0  Good option for person with swallowing/head ti...
# 1                  She has very painful hands, wrist
# 2  This is a good cup for my 92 year old dad who ...
# 3                                      Dysphagia Cup
# 4  Excellent cup for those that need help with dr...
#
#                                               review                star  \
# 0  I bought one of these for my mother who suffer...  4.0 out of 5 stars
# 1  I bought this mug to help my 80 year old mom w...  5.0 out of 5 stars
# 2  This is a good cup for my 92 year old dad who ...  5.0 out of 5 stars
# 3  This is a good example of considered industria...  5.0 out of 5 stars
# 4  Sturdy plastic cup that won't tip over, thanks...  5.0 out of 5 stars
#
#                  Product
# 0  soupiweightedbase.csv
# 1  soupiweightedbase.csv
# 2  soupiweightedbase.csv
# 3  soupiweightedbase.csv
# 4  soupiweightedbase.csv
#                                    title  \
# 0               This cup is a lifesaver.
# 1  Nice concept, but lacking in function
# 2                                   Safe
# 3          Ease of handling, drink from.
# 4                      Not as advertised
#
#                                               review                star  \
# 0  Excellent produce!My mother (87 yrs old) is in...  5.0 out of 5 stars
# 1  It works as long as you have a good sized coff...  5.0 out of 5 stars
# 2  Excellent for dementia individuals who have ch...  5.0 out of 5 stars
# 3  Purchased for Alzheimer’s patient with difficu...  4.0 out of 5 stars
# 4  Would love to give this no stars!NOT LEAK PROO...  1.0 out of 5 stars
#
#            Product
# 0  soupkirimon.csv
# 1  soupkirimon.csv
# 2  soupkirimon.csv
# 3  soupkirimon.csv
# 4  soupkirimon.csv
#                                                title  \
# 0                  Overpriced but works as described
# 1  The Provale Cup dispenses 1 Tbsp of un-thicken...
# 2  A truly amazing cup to assist my husband in sw...
# 3                                         Overpriced
# 4                Does Amazon want to keep customers?
#
#                                               review                star  \
# 0  I Initially gave this cup 1 star because it le...  3.0 out of 5 stars
# 1  After my husband's series of seizures it left ...  5.0 out of 5 stars
# 2  A truly amazing cup to assist my husband in sw...  5.0 out of 5 stars
# 3  This cup is overpriced considering the fact th...  2.0 out of 5 stars
# 4  Unfortunately these cups were flawed in that t...  3.0 out of 5 stars
#
#            Product
# 0  soupprovale.csv
# 1  soupprovale.csv
# 2  soupprovale.csv
# 3  soupprovale.csv
# 4  soupprovale.csv
#                                                title  \
# 0  This is an amazing product for people that hav...
# 1                                         Works well
# 2                                       Super straw!
# 3                                       Easy to lose
# 4                                    Waste of money!
#
#                                               review                star  \
# 0  This product has been a dysphagia lifesaver!  ...  5.0 out of 5 stars
# 1  This straw made life so much better for my pat...  5.0 out of 5 stars
# 2  This is a great item and a godsend for my elde...  5.0 out of 5 stars
# 3                      Hard  to wash.  Easy to lose.  3.0 out of 5 stars
# 4  These don't work well at all! I don't recommen...  1.0 out of 5 stars
#
#                   Product
# 0  soupsafestrawthick.csv
# 1  soupsafestrawthick.csv
# 2  soupsafestrawthick.csv
# 3  soupsafestrawthick.csv
# 4  soupsafestrawthick.csv
#                                                title  \
# 0                     Get rid of thickened liquids!!
# 1  Nurses at our hospital came to see how this wo...
# 2                              DO YOU WANT TO CHOKE?
# 3  Worked great for a couple of weeks for my daug...
# 4  Provides small sip to help with swallowing and...
#
#                                               review                star  \
# 0  The SafeStaw is almost a miracle. After a stro...  5.0 out of 5 stars
# 1  My wife is swalling problems and we needed to ...  5.0 out of 5 stars
# 2  BOUGH THIS DEVICE FOR DYSPHAGIA, BUT MAKES ME ...  1.0 out of 5 stars
# 3  Worked great for a couple of weeks for my daug...  5.0 out of 5 stars
# 4     Great product! Follow directions and out works  5.0 out of 5 stars
#
#                  Product
# 0  soupsafestrawthin.csv
# 1  soupsafestrawthin.csv
# 2  soupsafestrawthin.csv
# 3  soupsafestrawthin.csv
# 4  soupsafestrawthin.csv
#                                               title  \
# 0  Not style pictured, handles made for baby hands.
# 1                               Not made for adults
# 2        Hot Liquids Take on a Strong Plastic Taste
# 3                                    WASTE OF MONEY
# 4                                           Useless
#
#                                               review                star  \
# 0  I also received the cup with the tiny handles ...  1.0 out of 5 stars
# 1  This cup is being sold as an Adult cup, it is ...  1.0 out of 5 stars
# 2  This cup is fine for cold liquids, but if you ...  2.0 out of 5 stars
# 3  After reading the reviews, only a handful rece...  1.0 out of 5 stars
# 4  This was definitely designed as a kids sippy c...  1.0 out of 5 stars
#
#            Product
# 0  soupsammons.csv
# 1  soupsammons.csv
# 2  soupsammons.csv
# 3  soupsammons.csv
# 4  soupsammons.csv
#                                                title  \
# 0                           Nutrition Problem Solved
# 1                                          Lewy Who?
# 2                        A big help for the bedbound
# 3                                It really does help
# 4  Thanks to only two parts is easy to clean and ...
#
#                                               review                star  \
# 0  I've ordered a total of 4 of these cups. They ...  5.0 out of 5 stars
# 1  This cup has been great for my brother who has...  5.0 out of 5 stars
# 2  My father has late stage lung cancer and is no...  5.0 out of 5 stars
# 3  This is my second order.  I ordered the first ...  5.0 out of 5 stars
# 4  I have 2 of these for my father who is on hosp...  5.0 out of 5 stars
#
#       Product
# 0  soupsp.csv
# 1  soupsp.csv
# 2  soupsp.csv
# 3  soupsp.csv
# 4  soupsp.csv

# %%
all_reviews_df
# Out:
#                                            title  \
# 0                    It is great for me overall!
# 1                    Easy straws for the elderly
# 2                                   4-5 time use
# 3       You have to push the straw in very hard!
# 4                               Difficult to use
# ..                                           ...
# 121                  Great spill-proof product!!
# 122                                   Five Stars
# 123                                  works great
# 124  Great cup for elderly and surgery recovery!
# 125                                   Five Stars
#
#                                                 review                star  \
# 0    Really good for me, with difficulty swallowing...  5.0 out of 5 stars
# 1    It doesn’t work for me I have no suction my th...  1.0 out of 5 stars
# 2                             They don’t last too long  3.0 out of 5 stars
# 3    It helped my sister drink water again after ha...  5.0 out of 5 stars
# 4                                    Difficult to use.  2.0 out of 5 stars
# ..                                                 ...                 ...
# 121  My dad used these cups when he was in an ortho...  5.0 out of 5 stars
# 122                            Very helpful for my Mom  5.0 out of 5 stars
# 123  I bought this cup for my father who is bedridd...  5.0 out of 5 stars
# 124  Works as advertised.  Very helpful following m...  5.0 out of 5 stars
# 125                    Great product and a great price  5.0 out of 5 stars
#
#                  Product
# 0    soupbionixthick.csv
# 1    soupbionixthick.csv
# 2    soupbionixthick.csv
# 3    soupbionixthick.csv
# 4    soupbionixthick.csv
# ..                   ...
# 121           soupsp.csv
# 122           soupsp.csv
# 123           soupsp.csv
# 124           soupsp.csv
# 125           soupsp.csv
#
# [718 rows x 4 columns]

# %%
list_of_products = all_reviews_df.Product.unique()

# %%
list_of_products
# Out:
# array(['soupbionixthick.csv', 'soupbionixthin.csv', 'soupikinsman.csv',
#        'soupindependenceplastic.csv', 'soupirije.csv',
#        'soupiweightedbase.csv', 'soupkirimon.csv', 'soupprovale.csv',
#        'soupsafestrawthick.csv', 'soupsafestrawthin.csv',
#        'soupsammons.csv', 'soupsp.csv'], dtype=object)

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (15,15), facecolor = None)
c = 1
for product in list_of_products:
    sub_data_frame = all_reviews_df[all_reviews_df["Product"] == product]
#     print(sub_data_frame)
    
    pol = lambda x: TextBlob(x).sentiment.polarity
    sub_data_frame['polarity'] = sub_data_frame['review'].apply(pol)
    
    num_bins = 10
    fig.add_subplot(4, 3, c)
    c = c + 1
    n, bins, patches = plt.hist(sub_data_frame.polarity, num_bins, facecolor='blue', alpha=0.5)
    plt.title(product)
    plt.xlabel('Polarity')
    plt.ylabel('# of Reviews')
    plt.subplots_adjust(left = 0., bottom = 0, right = 1, top = 1, wspace = 0.2, hspace = 0.2)
# Out:
# C:\Users\leey2\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = plt.figure(figsize = (15,15), facecolor = None)
c = 1
for product in list_of_products:
    sub_data_frame = all_reviews_df[all_reviews_df["Product"] == product]
#     print(sub_data_frame)
    
    sub = lambda x: TextBlob(x).sentiment.subjectivity
    sub_data_frame['subjectivity'] = sub_data_frame['review'].apply(pol)
    
    num_bins = 10
    fig.add_subplot(4, 3, c)
    c = c + 1
    n, bins, patches = plt.hist(sub_data_frame.subjectivity, num_bins, facecolor='blue', alpha=0.5)
    plt.title(product)
    plt.xlabel('Subjectivity')
    plt.ylabel('# of Reviews')
    plt.subplots_adjust(left = 0., bottom = 0, right = 1, top = 1, wspace = 0.2, hspace = 0.2)
# Out:
# C:\Users\leey2\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (20,20), facecolor = None)
c = 1
stop_words = set(STOPWORDS)
comment_words = ""
for product in list_of_products:
    sub_data_frame = all_reviews_df[all_reviews_df["Product"] == product]
    
    for i in sub_data_frame.review: 
        i = str(i) 
        separate = i.split() 
        for j in range(len(separate)): 
            separate[j] = separate[j].lower() 
      
        comment_words += " ".join(separate)+" "
    final_wordcloud = WordCloud(width = 500, height = 700, 
                background_color ='black', 
                stopwords = stop_words, 
                min_font_size = 8).generate(comment_words)

    fig.add_subplot(4, 3, c)
    c = c + 1
    plt.imshow(final_wordcloud) 
    plt.axis("off") 
    plt.title(product)
    plt.subplots_adjust(left = 0., bottom = 0, right = 0.5, top = 1, wspace = 0.05, hspace = 0.05)
    plt.show

# %%
#Creates Polarity Instagram 

pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity


all_reviews_df['polarity'] = all_reviews_df['review'].apply(pol)
all_reviews_df['subjectivity'] = all_reviews_df['review'].apply(sub)


num_bins = 10
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(all_reviews_df.polarity, num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Number of Reviews')
plt.title('Polarity Score of All Dysphagia Products')
plt.show();

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.distplot(all_reviews_df['subjectivity'], hist=True, kde=True, 
             bins=int(30), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
plt.xlim([-0.001,1.001])
plt.xlabel('Subjectivity', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.title('Subjectivity Score of All Dysphagia Products', fontsize=15)
# Out:
# C:\Users\leey2\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Subjectivity Score of All Dysphagia Products')

# %%
#Creates a WordCloud out of all the reviews 

stop_words = set(STOPWORDS)
comment_words = ""
for i in all_reviews_df.review: 
    i = str(i) 
    separate = i.split() 
    for j in range(len(separate)): 
        separate[j] = separate[j].lower() 
      
    comment_words += " ".join(separate)+" "
final_wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stop_words, 
                min_font_size = 10).generate(comment_words)
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(final_wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
print("Word Cloud for All Dysphagia Products")
  
plt.show()
# Out:
# Word Cloud for All Dysphagia Products

# %%
df1 = all_reviews_df[["Product", "review"]]
df1
# Out:
#                  Product                                             review
# 0    soupbionixthick.csv  Really good for me, with difficulty swallowing...
# 1    soupbionixthick.csv  It doesn’t work for me I have no suction my th...
# 2    soupbionixthick.csv                           They don’t last too long
# 3    soupbionixthick.csv  It helped my sister drink water again after ha...
# 4    soupbionixthick.csv                                  Difficult to use.
# ..                   ...                                                ...
# 121           soupsp.csv  My dad used these cups when he was in an ortho...
# 122           soupsp.csv                            Very helpful for my Mom
# 123           soupsp.csv  I bought this cup for my father who is bedridd...
# 124           soupsp.csv  Works as advertised.  Very helpful following m...
# 125           soupsp.csv                    Great product and a great price
#
# [718 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(df["review"])

# %%
X
# Out:
# <126x793 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1685 stored elements in Compressed Sparse Row format>

# %%
inertia=[]
for k in range(2,126):
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=25).fit(X)
    inertia.append(kmeans.inertia_)
# Out:
# C:\Users\leey2\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: ConvergenceWarning: Number of distinct clusters (122) found smaller than n_clusters (123). Possibly due to duplicate points in X.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\leey2\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: ConvergenceWarning: Number of distinct clusters (122) found smaller than n_clusters (124). Possibly due to duplicate points in X.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\leey2\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:3: ConvergenceWarning: Number of distinct clusters (122) found smaller than n_clusters (125). Possibly due to duplicate points in X.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.plot(range (2,126),inertia)

# %%
test_k = 5
kmeans = KMeans(n_clusters=test_k, random_state=0,n_init=25).fit(X)
order_centroids = kmeans.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()

for i in range(test_k):
    print("Cluster")
    print(i)
    for ind in order_centroids[i, :10]:
        print(terms[ind])
# Out:
# Cluster
# 0
# perfect
# works
# daughter
# used
# tried
# product
# loves
# happy
# ok
# cheap
# Cluster
# 1
# great
# works
# cup
# dementia
# worked
# price
# granddaughter
# spill
# loved
# disables
# Cluster
# 2
# good
# elderly
# mother
# plastic
# didn
# law
# handy
# rest
# thing
# bed
# Cluster
# 3
# cup
# small
# mom
# lid
# adult
# doesn
# liquids
# dad
# use
# needed
# Cluster
# 4
# flow
# hole
# finger
# control
# drink
# liquid
# does
# spilling
# cup
# able

# %%
for i in X:
    print(vectorizer.inverse_transform(i))
    print(kmeans.predict(i))
# Out:
# [array(['marked', 'noticed', 'discolored', 'just', 'taste', 'smell',
#        'residual', 'product', 'true', 'inside', 'stain', 'slightly',
#        'does', 'tomato', 'negative', 'time', 'recovery', 'impressed',
#        'told', 'eating', 'asked', 'surgeon', 'plastic', 'pour', 'cup',
#        'measuring', 'glass', 'soup', 'heat', 'microwave', 'don', 'shelf',
#        'dw', 'hand', 'wash', 'easy', 'sitting', 'use', 'laying', 'used',
#        'says', 'description', 'finding', 'eat', 'able', 'weight',
#        'losing', 'rapidly', 'solution', 'perfect', 'surgery',
#        'reconstruction', 'facial', 'waiting', 'chew', 'unable', 'foods',
#        'similar', 'soups', 'creamed', 'smoothies', 'drinking', 'great',
#        'work', 'cups', 'total', 'ordered', 've'], dtype='<U14')]
# [2]
# [array(['drink', 'reclined', 'flexy', 'straw', 'flexible', 'uses', 'grip',
#        'good', 'worked', 'size', 'tiny', 'small', 'hands', 'doesn',
#        'parkinson', 'like', 'stiffness', 'control', 'motor', 'includes',
#        'alzheimer', 'degenerative', 'form', 'common', '2nd', 'dementia',
#        'body', 'lewy', 'brother', 'cup', 'great'], dtype='<U14')]
# [2]
# [array(['thank', 'came', 'love', 'dad', 'embarrassed', 'child', 'look',
#        'spills', 'frustrating', 'tilting', 'allows', 'tipping', 'avoid',
#        'maneuvering', 'lot', 'require', 'help', 'straws', 'easier',
#        'spilling', 'bedbound', 'weak', 'cancer', 'lung', 'stage', 'late',
#        'father', 'doesn', 'like', 'cup', 'hand', 'drinking'], dtype='<U14')]
# [2]
# [array(['price', 'lastly', 'ensure', 'drinks', 'likes', 'additionally',
#        'bed', 'fed', 'actually', 'hole', 'mouth', 'mess', 'greater',
#        'intake', 'feeding', 'spoon', 'spillage', 'decreased',
#        'substantially', 'way', 'creamy', 'make', 'liquid', 'little',
#        'food', 'pureed', 'mixed', 'vascular', 'swallowing', 'trouble',
#        'mother', 'elderly', 'order', 'second', 'reclined', 'good',
#        'worked', 'size', 'like', 'control', 'dementia', 'slightly',
#        'eating', 'cup', 'soup', 'use', 'able', 'great', 'ordered'],
#       dtype='<U14')]
# [2]
# [array(['sanitize', 'clean', 'parts', 'thanks', 'dropped', 'knocked',
#        'attached', 'remains', 'remove', 'simple', 'reducing', 'proof',
#        'spill', 'confusion', 'decreases', 'lid', 'opposite', 'tips',
#        'fluids', 'thicker', 'flow', 'accommodates', 'larger', 'large',
#        'spout', 'liquids', 'nectar', 'requires', 'hospice', 'hole',
#        'father', 'drink', 'straw', 'control', 'plastic', 'cup', 'easy',
#        'able'], dtype='<U14')]
# [2]
# [array(['floor', 'come', 'pretty', 'stays', 'safe', 'dishwasher', 'hold',
#        'did', 'glad', 'switched', 'broken', 'constantly', 'frequently',
#        'new', 'buy', 'having', 'ozs', 'held', 'grasp', 'ones',
#        'accidentally', 'knock', 'tendency', 'bottoms', 'weighted',
#        'glasses', 'using', 'previously', 'learned', 'easily', 'stroke',
#        'mom', 'pictured', 'received', 'dropped', 'remove', 'lid', 'flow',
#        'liquid', 'swallowing', 'trouble', 'uses', 'like', 'control',
#        'just', 'cup', 'shelf', 'hand', 'use', 'ordered'], dtype='<U14')]
# [2]
# [array(['ideal', 'heavy', 'handled', 'dual', 'hours', 'happened', 'hadn',
#        'stars', 'given', 'pry', 'photo', 'broke', 'day', 'end',
#        'unfortunately', 'position', 'reclining', 'loved', 'bedridden',
#        'alzheimers', 'aunt', 'bought', 'promising', 'looked', 'quickly',
#        'arrived', 'dropped', 'bed', 'elderly', 'drink', 'just', 'time',
#        'plastic', 'cup', 'use', 'cups'], dtype='<U14')]
# [2]
# [array(['fault', 'preference', 'tea', 'didn', 'hot', 'couple', 'extras',
#        'buying', 'ended', 'supplement', 'nutritional', 'juice', 'morning',
#        'gave', 'water', 'kept', 'comfortable', 'lay', 'uncomfortable',
#        'upright', 'sit', 'allowed', 'hospital', 'life', 'months', 'bound',
#        'position', 'safe', 'mom', 'clean', 'liquids', 'bed', 'drink',
#        'like', 'just', 'product', 'plastic'], dtype='<U14')]
# [2]
# [array(['accurate', 'measurements', 'wide', 'sip', 'abdominal', 'secure',
#        'screw', 'slides', 'cap', 'air', 'blocking', 'end', 'lid', 'flow',
#        'spout', 'lastly', 'hole', 'lot', 'straw', 'doesn', 'control',
#        'don', 'surgery'], dtype='<U14')]
# [2]
# [array(['regulate', 'makes', 'change', 'choking', 'lessened',
#        'dramatically', 'chokes', 'result', 'weaken', 'reflex', 'swallow',
#        'causing', 'issue', 'health', 'end', 'bought', 'easily', 'simple',
#        'flow', 'spout', 'hole', 'liquid', 'dad', 'avoid', 'easier',
#        'weak', 'cup'], dtype='<U14')]
# [2]
# [array(['charge', 'shipping', 'priced', 'reasonably', 'dishes', 'manages',
#        'white', 'plain', 'looks', 'boring', 'yes', 'entire', 'bad',
#        'nearly', 'disease', 'husband', 'buying', 'knocked', 'spill',
#        'drinks', 'liquid', 'little', 'order', 'spilling', 'worked',
#        'parkinson', 'just', 'does', 'glass', 'work', 'cups'], dtype='<U14')]
# [2]
# [array(['drops', 'flies', 'takes', 'comes', 'adult', 'design', 'using',
#        'lid', 'liquids', 'dementia', 'negative', 'cup', 'easy', 'great'],
#       dtype='<U14')]
# [0]
# [array(['return', 'helpful', 'really', 'amazon', 'slid', 'grandfather',
#        'afraid', 'returned', 'maybe', 'screwed', 'better', 'fits', 'snug',
#        'spill', 'lid', 'cup'], dtype='<U14')]
# [2]
# [array(['substitutes', 'meal', 'feed', 'saved', 'literately', 'advanced',
#        'strokes', 'comfortable', 'life', 'liquid', 'mother', 'drink',
#        'alzheimer', 'eat', 'unable'], dtype='<U14')]
# [2]
# [array(['expected', 'graduated', 'fame', 'claim', 'needed', 'think', 'fit',
#        'slip', 'drowned', 'vacuum', 'client', 'got', 'bad', 'makes',
#        'lid', 'flow', 'doesn', 'like', 'control', 'dementia', 'marked',
#        'just', 'cup', 'measuring', 'don', 'work'], dtype='<U14')]
# [2]
# [array(['processing', 'cover', 'fingers', 'entirely', 'idea', 'ms',
#        'purchased', 'finger', 'user', 'state', 'updated', 'needs', 'info',
#        'shown', 'return', 'really', 'amazon', 'end', 'hold', 'easily',
#        'flow', 'hole', 'make', 'liquid', 'thank', 'stage', 'control',
#        'brother', 'product', 'does', 'cup', 'unable', 'great', 'work'],
#       dtype='<U14')]
# [2]
# [array(['stronger', 'holder', 'watertight', 'unnecessary', 'designed',
#        'awkward', 'mouthpiece', 'minimal', 'patient', 'convalescing',
#        'fit', 'water', 'bedridden', 'bought', 'hold', 'frequently',
#        'using', 'lid', 'fluids', 'thicker', 'flow', 'liquids', 'mouth',
#        'help', 'straws', 'weak', 'drink', 'straw', 'control', 'product',
#        'cup', 'use', 'work'], dtype='<U14')]
# [2]
# [array(['recommend', 'supply', 'toddler', 'times', 'kinda', 'snap',
#        'covering', 'shoots', 'member', 'family', 'finger', 'screw',
#        'slides', 'buying', 'ended', 'water', 'sit', 'lid', 'hole',
#        'little', 'came', 'drink', 'good', 'doesn', 'just', 'cup', 'don'],
#       dtype='<U14')]
# [2]
# [array(['highly', 'comfortably', 'helped', 'saw', 'soon', 'skeptical',
#        'hubby', 'expectations', 'met', 'ailing', 'recommend', 'got',
#        'mom', 'liquids', 'mother', 'drink', 'cup'], dtype='<U14')]
# [0]
# [array(['soaking', 'prevent', 'works', 'sippy', 'wet', 'towel', 'member',
#        'family', 'finger', 'better', 'sit', 'bedridden', 'buy', 'flow',
#        'hole', 'decreased', 'order', 'child', 'drink', 'cup'],
#       dtype='<U14')]
# [2]
# [array(['accidental', 'eliminate', 'safely', 'prone', 'semi', 'cheap',
#        'durable', 'things', 'slow', 'away', 'right', 'felt', 'dysphasia',
#        'issues', 'starting', 'helped', 'husband', 'comfortable',
#        'position', 'easily', 'clean', 'flow', 'liquid', 'spills', 'drink',
#        'control', 'plastic', 'cup', 'hand', 'wash', 'easy'], dtype='<U14')]
# [2]
# [array(['spoils', 'drop', 'shake', 'moms', 'chance', 'giving', 'thought',
#        'right', 'didn', 'spill', 'second', 'love', 'size', 'small',
#        'doesn', 'like', 'just', 'cup', 'hand'], dtype='<U14')]
# [0]
# [array(['printed', 'amounts', 'measurement', 'thing', 'assist', 'handles',
#        'weakness', 'arthritis', 'muscle', 'mug', 'clear', 'elderly',
#        'good', 'plastic'], dtype='<U14')]
# [0]
# [array(['case', 'long', 'tip', 'according', 'described', 'slow',
#        'covering', 'finger', 'water', 'flow', 'hole', 'spilling', 'doesn',
#        'does', 'cup', 'description', 'able', 'work'], dtype='<U14')]
# [2]
# [array(['dripping', 'important', 'properly', 'function', 'big', 'problem',
#        'ease', '94', 'sipper', 'long', 'loved', 'hold', 'liquids', 'dad',
#        'straw', 'cup', 'use', 'used'], dtype='<U14')]
# [2]
# [array(['derrames', 'los', 'evitan', 'se', 'herméticamente', 'cierra',
#        'tapa', 'espesas', 'las', 'útil', 'nosotros', 'pero', 'pequeño',
#        'más', 'orificio', 'el', 'modelo', 'existe', 'bebidas', 'clases',
#        'diferentes', 'vez', 'la', 'varios', 'usamos', 'pariente',
#        'alimentar', 'ayuda', 'gran', 'sido', 'ha', 'discapacidad',
#        'personas', 'para', 'vaso', 'este', 'español', 'seal', 'useful',
#        'smaller', 'model', 'kinds', 'different', 'relative', 'fantastic',
#        'disabilities', 'people', 'english', 'prevent', 'feed', 'cap',
#        'drinks', 'hole', 'spillage', 'help', 'time', 'cup', 'use'],
#       dtype='<U14')]
# [0]
# [array(['character', 'mouse', 'mickey', 'stand', 'soppy', 'liked',
#        'clumsy', 'night', 'try', 'table', 'bedside', 'want', 'thought',
#        'convalescing', 'idea', 'fits', 'sip', 'water', 'knock', 'spill',
#        'just', 'cup', 'glass'], dtype='<U14')]
# [2]
# [array(['disappointed', 'aging', 'tight', 'needed', 'adult', 'lid',
#        'small', 'cup'], dtype='<U14')]
# [0]
# [array(['hard', 'adult', 'sip', 'mom', 'small'], dtype='<U14')]
# [0]
# [array(['loves', 'exactly', 'dysphagia', 'onset', 'experiencing', 'son',
#        'assist', 'needed', 'eating', 'cup', 'foods'], dtype='<U14')]
# [0]
# [array(['money', 'waste', 'complete', 'pours', 'beverage', 'vent', 'place',
#        'finger', 'hole', 'does', 'work'], dtype='<U14')]
# [2]
# [array(['apart', 'substantial', 'come', 'clean', 'does', 'cup', 'easy',
#        'use'], dtype='<U14')]
# [2]
# [array(['wife', 'worthless', 'oz', '60', 'worth', 'money', 'thing',
#        'needs', 'water', 'day', 'way', 'drink', 'small'], dtype='<U14')]
# [2]
# [array(['rate', 'org', 'hdsa', 'huntington', 'suffering', 'wife', 'vent',
#        'exactly', 'needed', 'disease', 'flow', 'hole', 'control', 'able'],
#       dtype='<U14')]
# [2]
# [array(['definitely', 'confidence', 'old', 'years', '87', 'recommend',
#        'purchased', 'sip', 'gave', 'water', 'mom', 'cup'], dtype='<U14')]
# [0]
# [array(['choke', 'didnt', 'stages', 'grandma', 'end', 'bought', 'flow',
#        'liquid', 'help', 'drink', 'worked', 'control', 'dementia', 'able',
#        'perfect'], dtype='<U14')]
# [2]
# [array(['volume', 'ok', 'regular', 'tends', 'sippy', 'adult', 'ideal',
#        'mom', 'spill', 'mother', 'elderly', 'small', 'cup', 'perfect',
#        'cups'], dtype='<U14')]
# [0]
# [array(['occasion', 'opening', 'wouldn', 'limit', 'learning', 'choke',
#        'hard', 'helped', 'fit', 'result', 'swallow', 'bought', 'stroke',
#        'mom', 'flow', 'mouth', 'straw', 'small', 'time', 'cup'],
#       dtype='<U14')]
# [0]
# [array(['wanted', 'complaining', 'half', 'exaggerated', 'length', 'tip',
#        'photo', 'just'], dtype='<U14')]
# [0]
# [array(['removal', 'teeth', 'wisdom', 'straws', 'worked', 'cup', 'use',
#        'surgery', 'great'], dtype='<U14')]
# [2]
# [array(['tipped', 'multiple', 'patient', 'day', 'glasses', 'liquid',
#        'little', 'spills', 'spilling', 'parkinson', 'glass', 'used'],
#       dtype='<U14')]
# [2]
# [array(['generally', 'purpose', 'defeats', 'ultimately', 'included',
#        'stopper', 'disappointed', 'purchased', 'little', 'cup'],
#       dtype='<U14')]
# [2]
# [array(['problems', 'adaption', 'clever', 'people', 'assist', 'lid',
#        'swallowing', 'cup'], dtype='<U14')]
# [0]
# [array(['pair', 'ingest', 'speak', 'ability', 'limits', 'condition',
#        'painful', 'severely', 'neuralgia', 'trigeminal', 'wife', 'times',
#        'fluids', 'flow', 'drink', 'control', 'cup', 'hand', 'eat',
#        'perfect'], dtype='<U14')]
# [2]
# [array(['children', 'guess', 'sides', 'grids', 'wish', 'worry', 'yrs',
#        'old', '87', 'arthritis', 'drop', 'husband', 'heavy', 'bought',
#        'spill', 'lid', 'elderly', 'help', 'hands', 'does', 'plastic',
#        'glass', 'don'], dtype='<U14')]
# [0]
# [array(['cover', 'screwed', 'spill', 'cup', 'easy', 'great'], dtype='<U14')]
# [2]
# [array(['far', 'tilt', 'things', 'works', 'mouthpiece', 'mom', 'spills',
#        'straw', 'size', 'doesn', 'perfect'], dtype='<U14')]
# [0]
# [array(['sharp', 'excessively', 'rim', 'uncovered', 'okay', 'works', 'cup'],
#       dtype='<U14')]
# [0]
# [array(['slows', 'barely', 'flowing', 'stop', 'instructions', 'vent',
#        'place', 'finger', 'state', 'flow', 'hole', 'liquid'], dtype='<U14')]
# [2]
# [array(['leaked', 'constantly', 'knock', 'dad', 'drink', 'cup'],
#       dtype='<U14')]
# [2]
# [array(['seeing', 'dislike', 'homes', 'nursing', 'livings', 'assisted',
#        'wish', 'toddler', 'use', 'used', 'cups'], dtype='<U14')]
# [0]
# [array(['works', 'mom', 'dementia', 'great'], dtype='<U14')]
# [1]
# [array(['patients', 'opening', 'works', 'idea', 'using', 'larger', 'spout',
#        'make', 'size', 'alzheimer', 'just', 'cup', 'great', 'ordered'],
#       dtype='<U14')]
# [2]
# [array(['completely', 'stop', 'works', 'finger', 'stars', 'mom', 'flow',
#        'hole', 'little', 'doesn', 'parkinson', 'perfect'], dtype='<U14')]
# [2]
# [array(['serves', 'narrower', 'bit', 'getting', 'throat', 'parched',
#        'moisten', 'wish', 'purpose', 'night', 'drop', 'spill', 'spout',
#        'good', 'product', 'does', 'use'], dtype='<U14')]
# [2]
# [array(['person', 'ridden', 'ice', 'boost', 'matter', 'care', 'taking',
#        'works', 'hubby', 'tea', 'didn', 'loved', 'bed', 'liquid',
#        'worked', 'like', 'great'], dtype='<U14')]
# [2]
# [array(['cupo', 'buy', 'feeding', 'cup', 'drinking'], dtype='<U14')]
# [0]
# [array(['case', 'long', 'tip', 'according', 'described', 'slow',
#        'covering', 'finger', 'water', 'flow', 'hole', 'spilling', 'doesn',
#        'does', 'cup', 'description', 'able', 'work'], dtype='<U14')]
# [2]
# [array(['job', 'small', 'doesn'], dtype='<U14')]
# [0]
# [array(['finally', 'early', 'medicine', 'tried', 'leak', 'morning', 'gave',
#        'water'], dtype='<U14')]
# [0]
# [array(['described', 'just'], dtype='<U14')]
# [0]
# [array(['went', 'cracked', 'water'], dtype='<U14')]
# [0]
# [array(['light', 'works', 'needed', 'juice', 'morning', 'mom', 'little',
#        'spills', 'small', 'hand', 'use'], dtype='<U14')]
# [0]
# [array(['dress', 'shirt', 'drips', 'leaks', 'wife', 'ms', 'lid', 'use'],
#       dtype='<U14')]
# [2]
# [array(['pop', 'lightweight', 'sturdy', 'lids', 'tight', 'fit',
#        'dishwasher', 'love', 'drink', 'straw', 'easy', 'cups'],
#       dtype='<U14')]
# [0]
# [array(['provide', 'enabled', 'item', 'ridden', 'safely', 'purchased',
#        'liquids', 'bed', 'make', 'mother', 'easier', 'drink', 'straw',
#        'cup', 'used'], dtype='<U14')]
# [2]
# [array(['difficulty', 'daily', 'bought', 'mother', 'used'], dtype='<U14')]
# [0]
# [array(['residents', 'home', 'nursing', 'works'], dtype='<U14')]
# [0]
# [array(['works', 'great'], dtype='<U14')]
# [1]
# [array(['disappointing', 'head', 'lift', 'holding', 'choke', 'finger',
#        'makes', 'hole', 'spills', 'easier', 'drink', 'does', 'cup',
#        'unable'], dtype='<U14')]
# [2]
# [array(['daughter', 'perfect'], dtype='<U14')]
# [0]
# [array(['tree', 'dollar', 'sippee', 'baby', 'aspiration', 'problems',
#        'opening', 'big', 'ended', 'bought', 'using', 'mom', 'spout',
#        'elderly', 'straw', 'used', 'cups'], dtype='<U14')]
# [0]
# [array(['didn', 'good', 'work'], dtype='<U14')]
# [0]
# [array(['hunt', 'tried', 'different', 'cups'], dtype='<U14')]
# [0]
# [array(['dimensions', 'attention', 'pay', 'purpose', 'didn', 'mother',
#        'small', 'doesn', 'work', 'ordered'], dtype='<U14')]
# [0]
# [array(['pops', 'controlled', 'dropped', 'lid', 'flow'], dtype='<U14')]
# [0]
# [array(['rest', 'handy', 'bed', 'elderly'], dtype='<U14')]
# [0]
# [array(['wonderful', 'suffering', 'works', 'husband', 'parkinson',
#        'product'], dtype='<U14')]
# [2]
# [array(['great'], dtype='<U14')]
# [1]
# [array(['ok'], dtype='<U14')]
# [0]
# [array(['law', 'mother', 'elderly', 'worked'], dtype='<U14')]
# [0]
# [array(['child', 'size'], dtype='<U14')]
# [0]
# [array(['challenge', 'complex', 'answer', 'simple'], dtype='<U14')]
# [0]
# [array(['leaked', 'liquid', 'product'], dtype='<U14')]
# [2]
# [array(['geriatric', 'didn', 'mom', 'help'], dtype='<U14')]
# [0]
# [array(['controlling', 'required', 'flow', 'liquid', 'avoid', 'spilling',
#        'just'], dtype='<U14')]
# [2]
# [array(['difficult', 'extremely', 'save', 'money', 'returned', 'better',
#        'water', 'flow', 'control'], dtype='<U14')]
# [2]
# [array(['good'], dtype='<U14')]
# [0]
# [array(['happy', 'recommend', 'product'], dtype='<U14')]
# [2]
# [array(['handle', 'suggestion', 'throw', 'patients', 'case', 'described',
#        'drop', 'works', 'patient', 'alzheimers', 'arrived', 'stays',
#        'buy', 'grasp', 'dementia', 'time', 'cup', 'great'], dtype='<U14')]
# [1]
# [array(['ill', 'husband', 'perfect'], dtype='<U14')]
# [0]
# [array(['practice', 'difficulties', 'als', 'taking', 'thought',
#        'eliminate', 'feed', 'price', 'require', 'straw', 'great'],
#       dtype='<U14')]
# [2]
# [array(['cheap'], dtype='<U14')]
# [0]
# [array(['patient', 'trouble', 'laying', 'drinking'], dtype='<U14')]
# [0]
# [array(['expected'], dtype='<U14')]
# [0]
# [array(['convalescent', 'leaks', 'proof', 'spill', 'lid', 'small'],
#       dtype='<U14')]
# [0]
# [array(['welol', 'smooth', 'reduced', 'crumble', 'struggled', 'bottles',
#        'wheelchair', 'walker', 'walk', 'stuck', 'law', 'liked', 'works',
#        'recommend', 'idea', 'amazon', 'bad', 'water', 'day', 'arrived',
#        'spout', 'drinks', 'bed', 'intake', 'spills', 'help', 'father',
#        'product', 'plastic', 'pour', 'cup', 'hand', 'drinking', 'great',
#        'ordered'], dtype='<U14')]
# [2]
# [array(['awesome', 'grapefruit', 'limes', 'lemons', 'puree', 've'],
#       dtype='<U14')]
# [0]
# [array(['works', 'great'], dtype='<U14')]
# [1]
# [array(['lifesaving', 'jaw', 'daughter', 'needed', 'surgery'], dtype='<U14')]
# [0]
# [array(['wish', 'handles', 'works', 'great', 'cups'], dtype='<U14')]
# [1]
# [array(['looking', 'exactly', 'works', 'just', 'great'], dtype='<U14')]
# [1]
# [array(['loves', 'father'], dtype='<U14')]
# [0]
# [array(['non', 'loved', 'spill', 'cup', 'great', 'total'], dtype='<U14')]
# [2]
# [array(['op', 'post', 'oral', 'absolute', 'jaw'], dtype='<U14')]
# [0]
# [array(['quality', 'high', 'beverages', 'yo', '89', 'best', 'daily', 'buy',
#        'mother', 'spills'], dtype='<U14')]
# [0]
# [array(['granddaughter', 'cup', 'great'], dtype='<U14')]
# [1]
# [array(['protection', 'offer', 'stable', 'relatively', 'keeping', 'lying',
#        'hasn', 'spillage', 'mother', 'drink', 'straw', 'good', 'used'],
#       dtype='<U14')]
# [0]
# [array(['great'], dtype='<U14')]
# [1]
# [array(['delivered', 'nice', 'flow', 'time', 'cups'], dtype='<U14')]
# [2]
# [array(['great'], dtype='<U14')]
# [1]
# [array(['disables', 'husband', 'worked', 'great'], dtype='<U14')]
# [2]
# [array(['fine', 'self', 'button', 'thickened', 'receive', 'opening',
#        'needed', 'did', 'pictured', 'received', 'flow', 'larger',
#        'liquids', 'small', 'control', 'just', 'cup', 'cups'], dtype='<U14')]
# [2]
# [array(['isn', 'tight', 'smaller', 'expected', 'afraid', 'lid', 'spillage',
#        'cup'], dtype='<U14')]
# [0]
# [array(['ounces', 'supposed', 'marking', 'read', 'hardly', 'small', 'cup'],
#       dtype='<U14')]
# [0]
# [array(['directions', 'flo', 'fast', 'know', 'dont', 'choke', 'works',
#        'use', 'laying'], dtype='<U14')]
# [0]
# [array(['fitting', 'loose', 'fairly', 'lever', 'bites', 'release',
#        'designers', 'convalescent', 'holding', 'stop', 'ok', 'try',
#        'cover', 'finger', 'pretty', 'spill', 'flow', 'spout', 'hole',
#        'drink', 'does', 'cups'], dtype='<U14')]
# [2]
# [array(['sealing', '10', 'current', 'ups', 'mop', 'apartment', 'studio',
#        'moved', 'illness', 'lids', 'problems', 'old', 'years', 'case',
#        'tip', 'minimal', 'husband', 'ones', 'clean', 'liquid', 'avoid',
#        'cup', 'use', 'used', 'great', 'cups'], dtype='<U14')]
# [0]
# [array(['dangerous', 'restock', '20', 'stuff', 'wright', 'careful', 'cut',
#        'edges', 'razor', 'aware', 'pls', 'sharp', 'wanted', 'people',
#        'purchased', 'return', 'charge', 'actually', 'product', 'cup',
#        'cups'], dtype='<U14')]
# [2]
# [array(['pillow', 'turn', 'final', 'illness', 'head', 'useful', 'husband',
#        'spilling', 'drink'], dtype='<U14')]
# [0]
# [array(['honey', 'fine', 'difficulty', 'light', 'stroke', 'flow', 'spout',
#        'liquids', 'hole', 'little', 'swallowing', 'dad', 'small', 'just',
#        'cup', 'use', 'weight', 'great'], dtype='<U14')]
# [2]
# [array(['families', 'accurately', 'filled', 'orders', 'quick', 'vendor',
#        'internet', 'searched', 'facility', 'rehab', 'ortho', 'best',
#        'awesome', 'home', 'difficulty', 'finally', 'regular', 'amazon',
#        'price', 'order', 'second', 'came', 'dad', 'product', 'cup',
#        'used', 'drinking', 'cups', 'ordered'], dtype='<U14')]
# [2]
# [array(['helpful', 'mom'], dtype='<U14')]
# [0]
# [array(['purchase', 'perfectly', 'lifting', 'happy', 'things', 'works',
#        'bedridden', 'bought', 'weak', 'father', 'cup'], dtype='<U14')]
# [2]
# [array(['following', 'advertised', 'works', 'helpful', 'recovery',
#        'surgery'], dtype='<U14')]
# [0]
# [array(['price', 'product', 'great'], dtype='<U14')]
# [1]
