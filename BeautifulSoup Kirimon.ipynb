# %%
import requests
from bs4 import BeautifulSoup
myBaseUrl = "https://www.amazon.com/Kirimon-Control-Spill-Proof-Style/product-reviews/B086JP5K7H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber="
# for different product change this base url, should end with page number = 
start_urls = []
for i in range(1, 4): # for different product change second number in range to number of review pages + 1
    start_urls.append(myBaseUrl + str(i))
print(start_urls)
HEADERS = {
    'authority': 'www.amazon.com',
'method' : 'POST',
'path' : '/gp/redirection/uae.html',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
response = []
for i in start_urls:
    response.append(requests.get(i,headers=HEADERS))
print(response)
# Out:
# ['https://www.amazon.com/Kirimon-Control-Spill-Proof-Style/product-reviews/B086JP5K7H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1', 'https://www.amazon.com/Kirimon-Control-Spill-Proof-Style/product-reviews/B086JP5K7H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2', 'https://www.amazon.com/Kirimon-Control-Spill-Proof-Style/product-reviews/B086JP5K7H/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3']
# [<Response [200]>, <Response [200]>, <Response [200]>]

# %%
soup = []
for i in response:
    soup.append(BeautifulSoup(i.content))
review = []
for i in soup:
    review.append(i.findAll("span",{'class':"a-size-base review-text review-text-content"}))
for i in review:
    for j in i:
        print(j.text)
# Out:
#   Excellent produce!My mother (87 yrs old) is in a nursing home, under Hospice care, with throat cancer.  She is able to drink her meals, with this cup.
#
#
#
#
#   It works as long as you have a good sized coffee container and it is reasonably full.  Deep in a small or container or where it is near the bottom controlling the amount of coffee you scoop is difficult.
#
#
#
#
#   Excellent for dementia individuals who have choking issues and need thickened beverages, no straw required, which is good, straws promote aspiration of liquids into lungs.
#
#
#
#
#   Purchased for Alzheimer’s patient with difficulty holding items. The ridges make it easier and the “sippy” spout keeps her from getting too much liquids at once with her difficulty swallowing, possibly choking.
#
#
#
#
#   Would love to give this no stars!NOT LEAK PROOF!!!! Not even close! Liquids pour out it easily, just having it on its side liquids drain out, beyond disappointment
#
#
#
#
#   This cup really allows my elderly mom to feed herself soup.  It is sturdy and seems to tolerate the microwave and dishwasher just fine.
#
#
#
#
#   It is leak proof, thick, and easy to clean.
#
#
#
#
#   Just what we needed for family member in hospital bed
#
#
#
#
#   It is not by no means leak proof in any way. Not happy with these cups at all
#
#
#
#
#   Would not stay sealed
#
#
#
#
#   I was looking for a cup for an adult stroke patient and this looked ideal.  It is actually a child-sized cup, and I should have realized when I read who many ounces it holds.  Totally my fault that I didn't read the description more closely.  Still usable, I just have to refill more often. Other than that, it's great!
#
#
#
#
#   I would work great for special needs person with good hand mouth control.  Handle not secured made the “removable” but we needed it to be right/glued.  Moth spout was to long and kept hitting her teeth.  Great cup for more advanced users of special needs. Just wasn’t what we needed.
#
#
#
#
#   Not anything like I thought... way too small for an adult. If used by elderly they have hold their head back.  Hard to hold.  Saw photos of a man drinking and looked bigger.  Very disappointed
#
#
#
#
#   My mother in law is blind so we bought this for her. It's terrible! Leaks, spills. I've never received anything that I did not like from Amazon, but this was not a good purchase. We will throw it out.
#
#
#
#
#   Poor. Cheap quality
#
#
#
#
#   Product is fairly made. Handle unstable. Seal under lid falls out constantly when screwing on lid. Absolutely not spill/leak proof. I have to handle for my patients. Not as perceived for medical adaptive equipment. Entirely to costly for the poor quality of product.
#
#
#
#
#   Not leak proof. Tip over and it will still spill. We actually put a straw in it 4 my dad since too much drink comes out when he tips cup 2 drink.  Only plus is I can usually catch him b4 all of his drink ends up on the furniture.
#
#
#
#
#   It’s not spill proof
#
#
#
#
#   worthless...
#
#
#
#
#   Neither of the 2 lids prevent any kind of spill. Liquid will come out easily. The handle is so loose it promotes spilling.
#
#
#
#
#   Very small Cup and very thin material. Slip on handle is unstable. Not safe for a child and to small for audit use.
#
#
#
#
#   Not big enough
#
#
#
#
#   Small cup is easy to fill. Is NOT spill proof or spill resistant.
#
#
#
#
#   This cup is not spill proof. Disappointed
#
#
#
#
#   The cup is very sharp at the top .. I washed it twice and both times I cut the top of my hand. The handle moves a lot doesn’t have a good grip on the cup itself
#
#
#
#
#   This cup was smaller than I expected and the handle can move up & down slightly which made my 92-year old friend a little nervous when she first used it-so we secured it with a rubber band underneath the handle to stop the slipping. She also couldn’t tip the cup to her mouth to drink out of it so we now use straws in the spout and she likes that.
#
#
#
#
#   Thus does not control flow at all. Can't be used.
#
#
#
#
#   Disappointed in themCheap, no insulationPoor seal qualityLook like dollar storecupsThe only good feature is the long spout
#
#
#
#
#   This cup has been very helpful for my Father in law who has Parkeninsons and is in hospice it is easy to use and lightweight, an somewhat spillproof.
#
#
#
#
#   Got this f or someone  who has trouble  holding  things.  Works  well. They  love  it.

# %%
titles = []
for soupnum in soup:
    title = soupnum.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"})
    for i in title:
        print(i.text)
# Out:
# This cup is a lifesaver.
#
#
# Nice concept, but lacking in function
#
#
# Safe
#
#
# Ease of handling, drink from.
#
#
# Not as advertised
#
#
# Great for elderly folks who still want to feed themselves!
#
#
# Easy to handle
#
#
# Works greT
#
#
# This cup is not worth the money
#
#
# Leaks
#
#
# Child-sized
#
#
# Great cup for advanced special needs users, straw drinkers and good hand/head control.
#
#
# Not for elderly
#
#
# Terrible
#
#
# Handling for elderly
#
#
# Disappointed
#
#
# Not worth it.
#
#
# Not spill proof
#
#
# worthless....
#
#
# Not at all leak or spill proof
#
#
# Look for better product
#
#
# Not big enough
#
#
# Is not leak proof.
#
#
# Too small
#
#
# Dislike
#
#
# Ok Cup
#
#
# Not as describdd
#
#
# I was disappointed 🙁
#
#
# Works good
#
#
# Works  well

# %%
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
HEADERS = {
      'authority': 'www.amazon.com',
'method' : 'POST',
'path' : '/gp/redirection/uae.html',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
 
}
 
    # The webpage URL
URL = "https://www.amazon.com/Kirimon-Control-Spill-Proof-Style/dp/B086JP5K7H"
 
    # HTTP Request
webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
soup = BeautifulSoup(webpage.content, "lxml")
print("Product Rating =", get_rating(soup))
print("Number of Product Reviews =", get_review_count(soup))
# Out:
# Product Rating = 3.3 out of 5 stars
# Number of Product Reviews = 190 ratings
