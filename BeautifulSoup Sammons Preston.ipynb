# %%
import requests
from bs4 import BeautifulSoup
myBaseUrl = "https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber="
# for different product change this base url, should end with page number = 
start_urls = []
for i in range(1, 10): # for different product change second number in range to number of review pages + 1
    start_urls.append(myBaseUrl + str(i))
print(start_urls)
HEADERS = {
    'authority': 'www.amazon.com',
'method' : 'POST',
'path' : '/gp/redirection/uae.html',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
response = []
for i in start_urls:
    response.append(requests.get(i,headers=HEADERS))
print(response)
# Out:
# ['https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8', 'https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/product-reviews/B0716HD4SV/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9']
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %%
soup = []
for i in response:
    soup.append(BeautifulSoup(i.content))
review = []
for i in soup:
    review.append(i.findAll("span",{'class':"a-size-base review-text review-text-content"}))
for i in review:
    for j in i:
        print(j.text)
# Out:
#   I also received the cup with the tiny handles and a narrow base.  NOT WHAT IS PICTURED, NOT WHAT I ORDERED! Very disappointed.
#
#
#
#
#   This cup is being sold as an Adult cup, it is a babies cup. It is so small, the handles are way to small for an adult. Do not bother getting this unless you need it for a very small child.
#
#
#
#
#   This cup is fine for cold liquids, but if you put anything hot into it, like tea, coffee, or milk, it takes on a distinct taste of plastic.  I had washed it thoroughly by hand before using, and tried running it through the dishwasher to get rid of the plastic taste but nothing worked.  The item's description says it is good for either hot or cold liquids, but I advise against buying it with the intention of using for anything but cold.
#
#
#
#
#   After reading the reviews, only a handful received the wrong cup so I took a gamble and lost. IF YOU CHANGE THE PRODUCT, CHANGE THE PICTURE.  This is actually fraud. I could buy this cup in the dollar store.  It's absolutely useless. I don't think a child could get all fingers in the handles.
#
#
#
#
#   The handles are surprisingly small. I can only fit a couple of fingers in without squeezing, making it awkward to use for an adult
#
#
#
#
#   This was definitely designed as a kids sippy cup. My brother who has hand tremors took one look and said no. His arthritic finger couldn't hold the cup and CV he ani were a bit disappointed in the size i know it says it hols 8 oz. We soon realized every drink came in 10, 12 16 oz.  I couldn't even get my neighbor who has a 14 month old to take them. Into the donate bag.
#
#
#
#
#   I bought this for my father. The handles are so small that only a child’s hands could grip them.
#
#
#
#
#   I like having a 2 handle cup and though I checked making my coffee to fit the cup, the lid I wanted to use is to be inverted and if one did that, one would lose another ounce or so of coffee.  The sippy cup screwed on from the top but was difficult to remove.  I do not recommend to any average coffee drinker.I have ordered another company's larger cup.
#
#
#
#
#   It was a gift for an elderly friend, who had a stroke.  She was happy with the mug.  Just to be safe, I heated the liquid in a glass cup in the microwave and then poured it into the two-handled cup.  She drinks slowly, so I don't know how long the liquid stayed warm.  It is not insulated.
#
#
#
#
#   I know these work great for some.  Unfortunately, they didn't work out for us.  We ended up preferring the Kennedy Cup... sorry they just were a better fit.
#
#
#
#
#   This is a toddlers sippy cup. The handles are too small for my 85 yr old mom and the lid does not fasten in order to prevent spillage
#
#
#
#
#   It's way over priced.  Just buy a cheaper sippy cup. It just about holds one cup. I have doubts about the microwave safe...it's the wrong sort of plastic
#
#
#
#
#   This cup is perfect for my 95 year old great aunt. She has severe rheumatoid arthritis in her hands, the large handles allow her to pick up her cup without difficulty. The double handles make it easier for her to hold steady.
#
#
#
#
#   I actually use this for my one year old daughter for learning to hold a cup on her own. It's been successful so far. It's clear plastic and seems pretty tough, but I wouldn't put it in the dishwasher though. It's the size of an orange, so it isn't too big. The split is removable and easy to clean.
#
#
#
#
#   It's like an adult sippy cup . There are 2 things that i feel would improve this item. First the handles are too small for adult twisted arthritic fingers to grasp. Secondly I feel a 10oz  capacity would be better than the 8oz.
#
#
#
#
#   Worked great for letting me control the flow of liquid for my grandma in end stages of dementia. Stopped her from choking.
#
#
#
#
#   Dishwasher safe. Easy to grip. Choice of lid styles. Once spouse hospitalized, I brought cups there and nursing staff loves them.
#
#
#
#
#   I purchased this hoping it would be helpful for my aging dad but it looks like it is for a child. Handles are much to small. It went back.
#
#
#
#
#   Really bad. The lid just sits in the cup. Spillage a problem!
#
#
#
#
#   It would make a good kids cup.
#
#
#
#
#   My husband has Parkinson's disease and has difficulty with manual dexterity. This cup is great for his morning juice and for other drinking during the day. It also helps, I believe with his tendency to aspirate liquids. A real blessing!
#
#
#
#
#   I love the two handle cup with  tremors it is Exactly what I needed
#
#
#
#
#   i got this for my mother who has terrbile shakes, it does help her
#
#
#
#
#   Cups crack and leak at bottom center. Had to throw away half of all not orders. Product is in my opinion defective and does not stand up to claims made in marketing.
#
#
#
#
#   My husband had a stroke and had to use both hands to guide the cup to his mouth.  I thought of the 'tommy tippy' cups for kids, then saw this cup listed as an 'adult', thinking it would be bigger and hold more than a child's cup.  It is not. I saw child cups bigger than this cup.  I am very disappointed in this product and the way it was advertised.
#
#
#
#
#   This has been a great help.  Mom can handle this by herself.
#
#
#
#
#   Was able to pour liquids directly into mouth once patient was unable to drink through a straw or use a regular cup. No leakage with tight lid-to-cup fit.
#
#
#
#
#   Excellent product and reasonable price.  Bought for a stroke victim and this lets them drink and stay hydrated without spilling.
#
#
#
#
#   Perfect for Parkinson’s patients. Gives them some independence.
#
#
#
#
#   Overall good product for kids.
#
#
#
#
#   Probably allows too much liquid for one who is aspirating.
#
#
#
#
#   Used it for my dad when he was in hospice. It helped out greatly and made him feel independent while he was using it. I recommend this product for anyone who is bedridden.
#
#
#
#
#   Smaller in real life. More for a toddler than a grown up.
#
#
#
#
#   Regretting that I didn't read the reviews before purchasing. Its cheaply made. Handles way too small for adults. Don't purchase it. It should be removed from Amazon.
#
#
#
#
#   Finger holes are way too small for elderly disabled adult. This cup is for a child and was not disclosed in the product description..
#
#
#
#
#   My husband has Parkinson’s disease, so having an unbreakabke cup with two handles is nice.
#
#
#
#
#   the handles were too small for her to grab.the top did not stay onit leaked.very cheapdon't buy it
#
#
#
#
#   Too small and too expensive.
#
#
#
#
#   more for a child than an adult who is handicapped, we will make it work but not a good cup for my brother in law
#
#
#
#
#   To small hard to hold onto
#
#
#
#
#   This was just what I needed for my father who needed an adult sippy sup. Clear plastic comes with 2 lids, one with a sucking nub and one with a hole for a straw.
#
#
#
#
#   Got to work with my G-J Tube fed son. So that I could work with him on trying to get to eat by mouth again!
#
#
#
#
#   Mom loves it
#
#
#
#
#   small and easy to handle can be used for children or as an adaptive cup for adults.
#
#
#
#
#   Not what I expected. I thought it would be larger
#
#
#
#
#   Product is as posted!!!
#
#
#
#
#   Easy to use
#
#
#
#
#   handles are a little small for larger hands
#
#
#
#
#   My wife has Parkinson's (PSP) and uses this cup to have a more secure grasp.
#
#
#
#
#   Mom has  dementia
#
#
#
#
#   Very small. It is like a tea cup size. The company was wonderful when it came to returning the cup.
#
#
#
#
#   great product
#
#
#
#
#   THE RIGHT SIZE FOR MY HUSBAND'S COFFEE SINCE HE IS BEDRIDDEN.
#
#
#
#
#   A LITTLE TOO EXPENSIVE FOR MY TASTE.
#
#
#
#
#   wouldn't even secure fully drank kept coming out
#
#
#
#
#   Liked the sturdiness of the product.
#
#
#
#
#   Great
#
#
#
#
#   perfect for husband's 60th birthday gift
#
#
#
#
#   Very great for a loved one very fast to ship
#
#
#
#
#   My mom has Parkinson and this is very easy for her to hold and get the fluids she needs.
#
#
#
#
#   Very happy this product....
#
#
#
#
#   Not user friendly
#
#
#
#
#   It helps with everything I hoped for
#
#
#
#
#   Useless...Leakes like a sieve
#
#
#
#
#   Not as large as expected, it's very small and not very sturdy made. Not worth buying
#
#
#
#
#   Way too small
#
#
#
#
#   My mom has Parkinson's and it easy for her to hold and drink by herself.
#
#
#
#
#   Easy for my 93 year old mother to use
#
#
#
#
#   This cup was ordered for my special needs son.  I love it.  He handles it very well.  However, he chews on the drinking spout and I was wondering if I could just order new tops since the cups are fine.
#
#
#
#
#   Too small
#
#
#
#
#   My disabled husband can use it.
#
#
#
#
#   It still leaked out.
#
#
#
#
#   Please explain to me why there are openings on the lid of this cup.... you make the slightest movement & liquid comes out. Quality is great but be aware, the lid is useless.
#
#
#
#
#   The two lids and the size of the cup was perfect
#
#
#
#
#   Could have been a little larger
#
#
#
#
#   Cheap and small
#
#
#
#
#   Cheap
#
#
#
#
#   my husband
#
#
#
#
#   I thought I was going to use it for a toddler sippy cup.  Nope.  It is a good cup for adults though since it holds hot liquids too.  Sometimes you need a lid.  I especially like the easy dishwasher cleaning.
#
#
#
#
#   Good product
#
#
#
#
#   disappointed
#
#
#
#
#   This is identical to a child’s sippy cup without all the cute colors.  I bought this for my dad who is in hospice and having a difficult time lifting a cup. My mom wanted a lightweight cup with handles. It is both those things, but the handles are insanely small. Like 1 fingers worth for an adult man. Maybe this would work for an older woman or smaller person, but it was a huge disappointment for my situation. The picture shows me holding the cup. I can fit 2 fingers at most.
#
#
#
#
#   Works very well...durable
#
#
#
#
#   I didn't realize it would be so small.

# %%
titles = []
for soupnum in soup:
    title = soupnum.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"})
    for i in title:
        print(i.text)
# Out:
# Not style pictured, handles made for baby hands.
#
#
# Not made for adults
#
#
# Hot Liquids Take on a Strong Plastic Taste
#
#
# WASTE OF MONEY
#
#
# Tiny
#
#
# Useless
#
#
# For a child only
#
#
# Not Recommended
#
#
# Lightweight and easy to hold.
#
#
# Good product... just not for us.
#
#
# Handles to small for most adults
#
#
# It's a sippy cup for seniors
#
#
# Exactly what I was looking for
#
#
# Good for kids too!
#
#
# Handles should be larger.
#
#
# Great for seniors
#
#
# Must have for caregiving
#
#
# For a Child’s Hands
#
#
# Only good if yr an adult without dementia
#
#
# Kids cup.
#
#
# Exactly as described!
#
#
# Exactly what I needed
#
#
# works
#
#
# Poor product.
#
#
# Not as advertised.
#
#
# The two handles are perfect.
#
#
# Was able to pour liquids directly into mouth once patient ...
#
#
# Good quality.
#
#
# Double handle and lidded plastic glass
#
#
# Handles are too smail for adult hands.
#
#
# Patient likes it
#
#
# I recommend this product for anyone who is bedridden
#
#
# For small drinkers
#
#
# Junk
#
#
# finger holes too small
#
#
# so having an unbreakabke cup with two handles is nice.
#
#
# not good for my senior mom
#
#
# Holds less than six ounces.
#
#
# not for an adult
#
#
# Small size
#
#
# Just what I Needed
#
#
# Got to work with my G-J Tube fed son. ...
#
#
# It works great for mom
#
#
# Five Stars
#
#
# Get what you pay for
#
#
# All went well
#
#
# 2 handle cups are wonderful.
#
#
# Three Stars
#
#
# Very Helpful
#
#
# Awesome
#
#
# Very very small
#
#
# good product
#
#
# Five Stars
#
#
# CHEAPLY MADE
#
#
# not a good product
#
#
# Product durability
#
#
# Five Stars
#
#
# Five Stars
#
#
# Very great cups
#
#
# My mom loves it
#
#
# Very happy costumer....
#
#
# Only holds 4 oz of it spills
#
#
# Thank you
#
#
# Dont do it
#
#
# There are better sippy cups
#
#
# Too small
#
#
# Works great
#
#
# Cup for elderly person
#
#
# I love it. He handles it very well
#
#
# One Star
#
#
# Works for my husband.
#
#
# Not good
#
#
# Quality is great but be aware
#
#
# Adult sippy cup
#
#
# Works well for my situation
#
#
# Two Stars
#
#
# Cheap
#
#
# the sippy cup is leak poof
#
#
# Not for toddlers.
#
#
# Four Stars
#
#
# One Star
#
#
# Very small handles
#
#
# Perfect
#
#
# Two Stars

# %%
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
HEADERS = {
    'authority': 'www.amazon.com',
'method' : 'POST',
'path' : '/gp/redirection/uae.html',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
  
}
 
    # The webpage URL
URL = "https://www.amazon.com/Sammons-Preston-Independence-Two-Handled-Spillproof/dp/B0716HD4SV/"
 
    # HTTP Request
webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
soup = BeautifulSoup(webpage.content, "lxml")
print("Product Rating =", get_rating(soup))
print("Number of Product Reviews =", get_review_count(soup))
# Out:
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 329 ratings
