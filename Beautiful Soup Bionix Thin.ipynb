# %%
import requests
from bs4 import BeautifulSoup
myBaseUrl = "https://www.amazon.com/Bionix-Health-Safestraw-Drinking-Liquids/product-reviews/B00L3D2MZ4/ref=cm_cr_getr_d_paging_btm_next_4?ie=UTF8&reviewerType=all_reviews&pageNumber="
# for different product change this base url, should end with page number = 
start_urls = []
for i in range(1, 5): # for different product change second number in range to number of review pages + 1
    start_urls.append(myBaseUrl + str(i))

HEADERS = {
    'authority': 'www.amazon.com',
'method' : 'POST',
'path' : '/gp/redirection/singapore.html',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
response = []
for i in start_urls:
    response.append(requests.get(i,headers=HEADERS))
print(response)
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %%
#collects soup data
soups = []
for i in response:
    soups.append(BeautifulSoup(i.content))
    
#collects and cleans review data
reviews = []
for soup in soups:
    review = soup.findAll("span",{'class':"a-size-base review-text review-text-content"})
    for i in review:
        reviews.append(i.text)
strippedreviews = []
for review in reviews:
    strippedreviews.append(review.strip())

# %%
#collects and cleans title data 
titles = []
for soup in soups:
    title = soup.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"})
    for i in title:
        titles.append(i.text)
strippedtitles = []
for title in titles:
    strippedtitles.append(title.strip())

# %%
avg_rating = 3.7 #change this average as necessary
stars = []
for soup in soups:
    star = soup.findAll("span",{'class':"a-icon-alt"})
    for i in star: 
        stars.append(i.text)
strippedstars = [] #this list still contains the stars from the avg. rating, top positive review, and top negative review
for star in stars:
    strippedstars.append(star.strip())
#code to remove excess stars scraped from html 
finalstars = []
indexofavg_rating = 0; 
for i in range(len(strippedstars)):
    if str(avg_rating) in strippedstars[i]:
        indexofavg_rating = i
    elif i != indexofavg_rating:
        if i != indexofavg_rating + 1:
            if i != indexofavg_rating + 2:
                finalstars.append(strippedstars[i])

# %%
#creates a csv file with title and review data 
import pandas as pd    

df = pd.DataFrame(strippedtitles, columns=["title"])   
df.to_csv('soupsafestrawthin.csv', index=False)  #change name of csv file as needed 
read = pd.read_csv("soupsafestrawthin.csv")
read["review"] = strippedreviews
read.to_csv("soupsafestrawthin.csv", index=False)
read["star"] = finalstars
read.to_csv("soupsafestrawthin.csv", index=False)
df = pd.read_csv("soupsafestrawthin.csv")

# %%
from textblob import TextBlob
pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity
df['polarity'] = df['review'].apply(pol)
df['subjectivity'] = df['review'].apply(sub)
df
# Out:
#                                                 title  \
# 0   Frustration for memory patients discourages th...
# 1                      Doesn’t do the job as expected
# 2                                 Bellow expectations
# 3                                   Excellent product
# 4        Great product but prepare for learning curve
# 5                                        Doesn't work
# 6                                            Works ok
# 7                                         Didn't Work
# 8                               Helps with swallowing
# 9                                   Wonderful product
# 10                                              Helps
# 11          As product description states works great
# 12                                         Five Stars
# 13                                           Awesome!
# 14             Great and does what its supposed to do
# 15                       Does Help Dysphagia Patients
# 16    Has Learning Curve, Needs Assembly Instructions
# 17  Helpful BUT No Instructions / Drinking Straw R...
# 18                         Less Nauseous and less Gas
# 19                                   for thin liquids
# 20                       Doesn't work with all straws
# 21                 Needs one important issue improved
# 22  Good concept.  But it was not easy enough to m...
# 23                        Did not work for my husband
# 24                          It was recommended by a E
# 25                                       Don’t buy it
# 26                               Advised to use this.
# 27                                  Straw Works Great
# 28                                          Potential
# 29                                    It does the job
# 30         GREAT FOR THOSE WHO HAVE TROUBLE EATING...
# 31                                    It's a succcess
# 32                                         Works well
# 33                                  Bit Tricky to Use
#
#                                                review                star  \
# 0   Recommended by Speech therapist:The package ca...  2.0 out of 5 stars
# 1   This device was recommended by a speech therap...  1.0 out of 5 stars
# 2   is difficult to be the first negative reviewer...  1.0 out of 5 stars
# 3   Item worked beyond expectations. My aunt can n...  5.0 out of 5 stars
# 4   This is a great product when used correctly an...  5.0 out of 5 stars
# 5   Did not work the way I was expecting. Tried it...  1.0 out of 5 stars
# 6   Works ok most of the time if you don’t over po...  5.0 out of 5 stars
# 7   This doesn't work! It still allows too much wa...  1.0 out of 5 stars
# 8   This accessory to the straw helps with drinkin...  5.0 out of 5 stars
# 9   These work great for my father who has had a s...  5.0 out of 5 stars
# 10                      Just what the terapest wanted  4.0 out of 5 stars
# 11      Love it so far for my father with dysphasia .  5.0 out of 5 stars
# 12  LOVE THIS, my sister has ALS & this helps ensu...  5.0 out of 5 stars
# 13  Works great for the residents in the healthcar...  5.0 out of 5 stars
# 14  Great product, easy to use and provides safety...  5.0 out of 5 stars
# 15  I received the Bionix Health at Home Safestraw...  5.0 out of 5 stars
# 16  This BIONIX HEALTH AT HOME SAFESTRAW DRINKING ...  2.0 out of 5 stars
# 17  Pros: Discretely dispenses 1 tsp of water or o...  4.0 out of 5 stars
# 18  I have slot of stomach issues including Barret...  5.0 out of 5 stars
# 19  Very important to note this white straw is for...  4.0 out of 5 stars
# 20  This straw was meant to work in conjunction wi...  4.0 out of 5 stars
# 21  Has a critical flaw sadly. I very much wanted ...  2.0 out of 5 stars
# 22  This is a good idea, and potentially a really ...  3.0 out of 5 stars
# 23  My husband said it didn't always dispense even...  1.0 out of 5 stars
# 24  I recently purchased this item for my son who ...  5.0 out of 5 stars
# 25  Awful. I have been a pediatric feeding special...  1.0 out of 5 stars
# 26  Purchased for another person who was advised b...  5.0 out of 5 stars
# 27  Bought this for a relative recovering from a s...  4.0 out of 5 stars
# 28  While the concept is great the actual product ...  3.0 out of 5 stars
# 29  Item came in a box explaining what it is and h...  3.0 out of 5 stars
# 30  My grandmother drinks a lot more than she eats...  5.0 out of 5 stars
# 31  With a hiatal hernia and dysphagia this is a s...  5.0 out of 5 stars
# 32  Easy to use. Need to cut a piece of a straw to...  5.0 out of 5 stars
# 33  Got this for Granny. No instructions were real...  3.0 out of 5 stars
#
#     polarity  subjectivity
# 0   0.337500      0.565152
# 1   0.250000      0.750000
# 2   0.101515      0.474852
# 3   0.175238      0.286667
# 4   0.240816      0.431293
# 5  -0.147222      0.558333
# 6   0.500000      0.500000
# 7   0.200000      0.200000
# 8  -0.062500      0.687500
# 9   0.507143      0.589286
# 10  0.000000      0.000000
# 11  0.300000      0.800000
# 12  0.300000      0.466667
# 13  1.000000      0.750000
# 14  0.411111      0.561111
# 15  0.079838      0.435951
# 16  0.007895      0.449224
# 17  0.021597      0.399259
# 18  0.173677      0.516887
# 19  0.065714      0.416071
# 20 -0.010880      0.424395
# 21  0.053056      0.616944
# 22  0.381667      0.448333
# 23  0.066667      0.500000
# 24  0.318333      0.460417
# 25 -0.333333      0.633333
# 26  0.000000      0.000000
# 27  0.400000      0.375000
# 28  0.102976      0.489807
# 29 -0.027778      0.675309
# 30  0.425000      0.587500
# 31  0.167000      0.614667
# 32  0.197222      0.630556
# 33  0.125000      0.387500
