# %%
import requests
from bs4 import BeautifulSoup
myBaseUrl = "https://www.amazon.com/Bionix-Health-Safestraw-Drinking-Liquids/product-reviews/B00L3D2MZ4/ref=cm_cr_getr_d_paging_btm_next_4?ie=UTF8&reviewerType=all_reviews&pageNumber="
# for different product change this base url, should end with page number = 
start_urls = []
for i in range(1, 5): # for different product change second number in range to number of review pages + 1
    start_urls.append(myBaseUrl + str(i))

HEADERS = {
    'authority': 'www.amazon.com',
'method' : 'POST',
'path' : '/gp/redirection/singapore.html',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
response = []
for i in start_urls:
    response.append(requests.get(i,headers=HEADERS))
print(response)
# Out:
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %%
#collects soup data
soups = []
for i in response:
    soups.append(BeautifulSoup(i.content))
    
#collects and cleans review data
reviews = []
for soup in soups:
    review = soup.findAll("span",{'class':"a-size-base review-text review-text-content"})
    for i in review:
        reviews.append(i.text)
strippedreviews = []
for review in reviews:
    strippedreviews.append(review.strip())

# %%
#collects and cleans title data 
titles = []
for soup in soups:
    title = soup.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"})
    for i in title:
        titles.append(i.text)
strippedtitles = []
for title in titles:
    strippedtitles.append(title.strip())

# %%
finalstars = []
for soup in soups:
    star = soup.findAll(attrs = {'data-hook':"review-star-rating"})
    for i in star: 
        finalstars.append(i.text)

# %%
#creates a csv file with title and review data 
import pandas as pd    

df = pd.DataFrame(strippedtitles, columns=["title"])   
df.to_csv('soupbionixthin.csv', index=False)  #change name of csv file as needed 
read = pd.read_csv("soupbionixthin.csv")
read["review"] = strippedreviews
read.to_csv("soupbionixthin.csv", index=False)
read["star"] = finalstars
read.to_csv("soupbionixthin.csv", index=False)
df = pd.read_csv("soupbionixthin.csv")

# %%
from textblob import TextBlob
pol = lambda x: TextBlob(x).sentiment.polarity
sub = lambda x: TextBlob(x).sentiment.subjectivity
df['polarity'] = df['review'].apply(pol)
df['subjectivity'] = df['review'].apply(sub)
df
# Out:
#                                                 title  \
# 0                    Mostly retired rehab nurse here.
# 1   Frustration for memory patients discourages th...
# 2                      Doesn’t do the job as expected
# 3                                 Bellow expectations
# 4                                   Excellent product
# 5        Great product but prepare for learning curve
# 6                                        Doesn't work
# 7                                            Works ok
# 8                                         Didn't Work
# 9                               Helps with swallowing
# 10                                  Wonderful product
# 11                                              Helps
# 12          As product description states works great
# 13                                         Five Stars
# 14                                           Awesome!
# 15             Great and does what its supposed to do
# 16                       Does Help Dysphagia Patients
# 17    Has Learning Curve, Needs Assembly Instructions
# 18  Helpful BUT No Instructions / Drinking Straw R...
# 19                         Less Nauseous and less Gas
# 20                                   for thin liquids
# 21                       Doesn't work with all straws
# 22                 Needs one important issue improved
# 23  Good concept.  But it was not easy enough to m...
# 24                        Did not work for my husband
# 25                          It was recommended by a E
# 26                                       Don’t buy it
# 27                               Advised to use this.
# 28                                  Straw Works Great
# 29                                          Potential
# 30                                    It does the job
# 31         GREAT FOR THOSE WHO HAVE TROUBLE EATING...
# 32                                    It's a succcess
# 33                                         Works well
# 34                                  Bit Tricky to Use
#
#                                                review                star  \
# 0   It's a good tool for someone cognitively intac...  4.0 out of 5 stars
# 1   Recommended by Speech therapist:The package ca...  2.0 out of 5 stars
# 2   This device was recommended by a speech therap...  1.0 out of 5 stars
# 3   is difficult to be the first negative reviewer...  1.0 out of 5 stars
# 4   Item worked beyond expectations. My aunt can n...  5.0 out of 5 stars
# 5   This is a great product when used correctly an...  5.0 out of 5 stars
# 6   Did not work the way I was expecting. Tried it...  1.0 out of 5 stars
# 7   Works ok most of the time if you don’t over po...  5.0 out of 5 stars
# 8   This doesn't work! It still allows too much wa...  1.0 out of 5 stars
# 9   This accessory to the straw helps with drinkin...  5.0 out of 5 stars
# 10  These work great for my father who has had a s...  5.0 out of 5 stars
# 11                      Just what the terapest wanted  4.0 out of 5 stars
# 12      Love it so far for my father with dysphasia .  5.0 out of 5 stars
# 13  LOVE THIS, my sister has ALS & this helps ensu...  5.0 out of 5 stars
# 14  Works great for the residents in the healthcar...  5.0 out of 5 stars
# 15  Great product, easy to use and provides safety...  5.0 out of 5 stars
# 16  I received the Bionix Health at Home Safestraw...  5.0 out of 5 stars
# 17  This BIONIX HEALTH AT HOME SAFESTRAW DRINKING ...  2.0 out of 5 stars
# 18  Pros: Discretely dispenses 1 tsp of water or o...  4.0 out of 5 stars
# 19  I have slot of stomach issues including Barret...  5.0 out of 5 stars
# 20  Very important to note this white straw is for...  4.0 out of 5 stars
# 21  This straw was meant to work in conjunction wi...  4.0 out of 5 stars
# 22  Has a critical flaw sadly. I very much wanted ...  2.0 out of 5 stars
# 23  This is a good idea, and potentially a really ...  3.0 out of 5 stars
# 24  My husband said it didn't always dispense even...  1.0 out of 5 stars
# 25  I recently purchased this item for my son who ...  5.0 out of 5 stars
# 26  Awful. I have been a pediatric feeding special...  1.0 out of 5 stars
# 27  Purchased for another person who was advised b...  5.0 out of 5 stars
# 28  Bought this for a relative recovering from a s...  4.0 out of 5 stars
# 29  While the concept is great the actual product ...  3.0 out of 5 stars
# 30  Item came in a box explaining what it is and h...  3.0 out of 5 stars
# 31  My grandmother drinks a lot more than she eats...  5.0 out of 5 stars
# 32  With a hiatal hernia and dysphagia this is a s...  5.0 out of 5 stars
# 33  Easy to use. Need to cut a piece of a straw to...  5.0 out of 5 stars
# 34  Got this for Granny. No instructions were real...  3.0 out of 5 stars
#
#     polarity  subjectivity
# 0   0.174395      0.521177
# 1   0.337500      0.565152
# 2   0.250000      0.750000
# 3   0.101515      0.474852
# 4   0.175238      0.286667
# 5   0.240816      0.431293
# 6  -0.147222      0.558333
# 7   0.500000      0.500000
# 8   0.200000      0.200000
# 9  -0.062500      0.687500
# 10  0.507143      0.589286
# 11  0.000000      0.000000
# 12  0.300000      0.800000
# 13  0.300000      0.466667
# 14  1.000000      0.750000
# 15  0.411111      0.561111
# 16  0.079838      0.435951
# 17  0.007895      0.449224
# 18  0.021597      0.399259
# 19  0.173677      0.516887
# 20  0.065714      0.416071
# 21 -0.010880      0.424395
# 22  0.053056      0.616944
# 23  0.381667      0.448333
# 24  0.066667      0.500000
# 25  0.318333      0.460417
# 26 -0.333333      0.633333
# 27  0.000000      0.000000
# 28  0.400000      0.375000
# 29  0.102976      0.489807
# 30 -0.027778      0.675309
# 31  0.425000      0.587500
# 32  0.167000      0.614667
# 33  0.197222      0.630556
# 34  0.125000      0.387500

# %%
import matplotlib.pyplot as plt
num_bins = 10
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(df.polarity, num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Number of Reviews')
plt.title('Histogram of Polarity Score')
plt.show();

# %%
mean1 = df['polarity'].mean()
print("Mean of Polarity: ", mean1)
median1 = df['polarity'].median()
print("Median of Polarity: ", median1)
# Out:
# Mean of Polarity:  0.1857613979163925
# Median of Polarity:  0.17367724867724868

# %%
from wordcloud import WordCloud, STOPWORDS
stop_words = set(STOPWORDS)
comment_words = ""
for i in df.review: 
    i = str(i) 
    separate = i.split() 
    for j in range(len(separate)): 
        separate[j] = separate[j].lower() 
      
    comment_words += " ".join(separate)+" "
final_wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stop_words, 
                min_font_size = 10).generate(comment_words)
plt.figure(figsize = (10, 10), facecolor = None) 
plt.imshow(final_wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.distplot(df['subjectivity'], hist=True, kde=True, 
             bins=int(30), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
plt.xlim([-0.001,1.001])
plt.xlabel('Subjectivity', fontsize=13)
plt.ylabel('Frequency', fontsize=13)
plt.title('Distribution of Subjectivity Score', fontsize=15)
# Out:
# c:\users\jaeme\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of Subjectivity Score')
