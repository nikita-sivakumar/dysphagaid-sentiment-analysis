# %%
import requests
from bs4 import BeautifulSoup
myBaseUrl = "https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber="
# for different product change this base url, should end with page number = 
start_urls = []
for i in range(1, 22): # for different product change second number in range to number of review pages + 1
    start_urls.append(myBaseUrl + str(i))
print(start_urls)
HEADERS = {
    'authority': 'fls-na.amazon.com',
'method' : 'GET',
'path' : '/1/batch/1/OP/ATVPDKIKX0DER:139-0997389-0276609:NQWXHVBY6MCGZ6ZFM91Q$uedata=s:%2Frd%2Fuedata%3Fat%26v%3D0.215337.0%26id%3DNQWXHVBY6MCGZ6ZFM91Q%26ctb%3D1%26m%3D1%26sc%3DNQWXHVBY6MCGZ6ZFM91Q%26pc%3D1452%26at%3D1452%26t%3D1612360136843%26pty%3DCustomerReviews%26spty%3DremoteProduct%26pti%3DB000NKGGGO%26tid%3DHPZXB0930WXTM9QYEJQV%26aftb%3D1%26ui%3D2:1453',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
response = []
for i in start_urls:
    response.append(requests.get(i,headers=HEADERS))
print(response)
# Out:
# ['https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20', 'https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/product-reviews/B000NKGGGO/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21']
# [<Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>, <Response [200]>]

# %%
soup = []
for i in response:
    soup.append(BeautifulSoup(i.content))
review = []
for i in soup:
    review.append(i.findAll("span",{'class':"a-size-base review-text review-text-content"}))
for i in review:
    for j in i:
        print(j.text)
# Out:
#   I Initially gave this cup 1 star because it leaked. I called the 800 number and the manufacturer walked me through the correct placement of the handles, which corrected the leaking issue. The handles snap on and once on, should not be removed again. When correctly attached, the handles should slightly overlap the top rim of the cup.  I was also instructed not to fill the cup all the way to the fill line and to take apart the two parts of the lid for cleaning. NThat said, I still feel the cup is overpriced. Also, my father does not like that he has to tip his head so far back to sip from the cup.
#
#
#
#
#   After my husband's series of seizures it left his esophagus damaged and he aspirated making it necessary to drink honey thickened fluids.  He has always be a huge water drinker and the thickened liquids did not quench his thirst at all.  The Provale Cup dispenses 1 Tbsp of un-thickened liquid at a time and it did satisfy his thirst until he was able to heal and drink liquids out of a normal cup again.
#
#
#
#
#   A truly amazing cup to assist my husband in swallowing without aspirating. It would be helpful if it was a little less costly so I would be able to have more that 1.I have recommended this product to many people.Thanks again.
#
#
#
#
#   This cup is overpriced considering the fact that it leaks non stop. I have to change my clients shirt any time she wants to drink anything other than water. For $36+ you'd think they could design this a little better. Breaks too easily, accidental drops are bound to happen with the population that need these devices.We're searching for another alternative rather than waste her limited funds on another of these.
#
#
#
#
#   Unfortunately these cups were flawed in that the 2 handles could not be placed on the cup because it caused leakage. We were able to make it work with one handle. But for the price, it was a cheap product. Returning them was not an option. We tried other types but to no avail. We found ourselves returning items and now that Amazon has this new return policy...(too many returns will knock me off their customer list) we decided to keep this defective product.
#
#
#
#
#   Since the product is the only one on the market that’s available to buy and ship to the EU, I understand that they are able to put their price so high and I thought if it is life saving coz my dad won’t drown himself while drinking it will be great. I have used the only other brand’s version before a lot and it was always leak proof and great but this one has a hole at the back of the rim of the lid which isn’t covered properly by the rim of the main cup.. I thought this was to stop vacuum but is way too big and more comes out of it there than the actual sipping opening of the cup. Which my dad noticed and started drinking out of there which made the whole cup pointless as it’s meant to only let 5mls out at once. The lid doesn’t click in and doesn’t screw on it’s a push on one but it doesn’t seem to go all the way on one side, I tried with a lot of force it’s annoying it doesn’t leak there though so the actual seal would be ok if it didn’t have a hole at the back. It’s good that the handles are removable, as first I put both on but my dad held it the wrong side and was trying to  drink with the sipping bit down... so I could remove and he can work is out now. He does often think that the opposite flap that we can use to open it is the bit where he should be drinking from it so I need to remind him that it’s the other way.Though, if the cup isn’t tipped backwards, it wouldn’t leak that much but it’s hard not to when someone is ill and has coordination problems.I tried to drink out of the cup several times and we used it with thickened fluids and I had to tip it almost 180 degrees to get all of the 5mls out but that makes it quite safe and when my dad does manage to use it it is a safe way of drinking for him so I’m happy to leave the cup with him to drink when unsupervised.Overall makes me feel safer about his drinking but could be better.
#
#
#
#
#   This cup was purchased for my husband who has Parkinson's. His swallowing of liquids needs to controlled in by using a cup that delivers only 2 tablespoons of liquid at one time which it does. The problem with the cup is that it does leak when the person is lifting the cup to their mouth.  In order to get the liquid the person needs to lift and tilt the cup quite high. This is very difficult for someone with Parkinson's whose motor skills are weak. Also, the price of this cup is much too expensive.
#
#
#
#
#   Can you say INEFFECTIVE ADULT SIPPY CUP. I bought this for my father who had stopped eating and drinking.  At a high recommendation I bought this cup as we were trying to reintroduce food and drink. The cup had oxymoron-ish directions and leaked. It was totally over priced for its ineffectiveness.  GARBAGE. I could have gone to the dollar store and bout a child's sippy cup with no leaks and no confusing directions.
#
#
#
#
#   This cup is NOT for everyone who has a dysphagia diagnosis. The person must be able to such the drink through the spout. This cup does not act like a sippy cut that "pours" into the mouth.  I ordered this for my brother, but he is unable to use it. I feel this information should be included in the product description.
#
#
#
#
#   This cup needs to be redesigned? You can not fill it to the "line". By the way,the line is very hard to see . If you fill it all the way to the invisible line it leaks.It's a good idea if only it worked. In my case it's not worth the trouble or the expense,it is overpriced.
#
#
#
#
#   My husband recently suffered aspiration pneumonia and was cautioned to drink small sips of liquid at a time.  He has mobility issues with his hands so his caregiver and I were attempting to control the amount of liquid he could sip.  He had stopped drinking as much, which is not a good thing.  This cup, suggested by dysphagia staff at Huntington Memorial Hospital in Pasadena, CA, has been the perfect solution.  It works as described and the handles make it easy for my husband to handle the cup himself.  I don't have to worry that he is taking in too much liquid at a time.  I highly recommend this product.
#
#
#
#
#   Bought this for my wife who has serious swallowing problems. She can only drink thickened beverages. It wasn't until we received this and read the paperwork that we found this does NOT work with thickened beverages. And it is not returnable. So I am stuck with a $40 paperwight
#
#
#
#
#   The cup was impossible to assemble, by me or the nurses in the nursing home, so I returned it.  Later he was giving one by a therapist in the nursing home, but it did not dispense enough liquid to be adequate for someone needing to push liquids to alleviate recurring UTI's.
#
#
#
#
#   The cup leaks no matter what we do. My dad has to have nectar thick liquids after his stroke and it doesn't work at all with anything thick. The cup seems really cheaply made and cost is super high. If you can find another brand, do it!
#
#
#
#
#   it does leak if you tilt it all the way up. If you drop it the lid comes off.it works........ ish and if you need one in a pinch.... and lets be honest, there is not much to choose from in this category. So if you need one, yeah but there is a lot of room for improvement.
#
#
#
#
#   Our doctor recommended the Provale cup after a swallow study.  This cup didn’t deliver measured liquid as expected. I purchased for my husband who has dysphasia due to progressive neurological disease.  He tried it for two weeks, but choked with most sips.  In order to get liquid out, he had to tip it to almost 90 degrees, and it sometimes leaked.  I felt we paid $36 for three pieces of plastic that just didn’t deliver what we needed.  Very disappointed.
#
#
#
#
#   Bad design. You have to tilt your head back to drink and that contributes to aspiration. Returned.
#
#
#
#
#   Purchased for my 93 year old mom while getting speech therapy for swallow issues. Product works great. We had to watch her to ensure she was only taking small sips, but this cup only lets her get small sips. This helped alleviate the worry out of having to constantly watch her. It is a bit hard to take apart for washing as it’s a snug fit, but it would leak if it were loose. Would highly recommend this product.
#
#
#
#
#   These cups have worked well for my mother who has Dysphagia.  They let her get off the thickened liquid that she hated and back onto water.The parts of the cup can be difficult to get apart and you have to be a little careful to keep from cracking the cup base. The brown lid cups I got release 1 tsp of fluid each time they are tipped up.
#
#
#
#
#   Perfect for my husband.  He is on tube feeding because of having trouble swallowing.  We don’t have any problems with him getting to much fluids.
#
#
#
#
#   Love this cup it does what I need it to do. The price is too much. But it’s either this or add thickeners and my husband would rather not drink.
#
#
#
#
#   Pathetic device that leaked all over the front of my wife, a stroke victim,  this strikes me as cruel joke on those who have swallowing difficulty, would strongly recommend NOT purchasing this item.  To which is not eligible for returns
#
#
#
#
#   The lid to this expensive cup leaks, unfortunately, I was under a lot of stress and lost track of time since I purchased this product which came highly recommended and when I went to return it, it was past the 30-day policy.  upon the 1st 2 uses, noticed it leaked and spilled all over my now disabled father. The purpose of the cup is great for a stroke victim only if it did not leak from the lid.
#
#
#
#
#   Bought this for my 100 yr old mother with dementia.  It was recommended by a speech therapist.
#
#
#
#
#   Was hard to snap together at first.  Works good at delivering a small amount of liquid.  I wish it was a bit more "adult" looking, but much better than a sippy cup for my teen just relearning how to drink/swallow.
#
#
#
#
#   This cup is WONDERFUL! My son has a tracheotomy and he has problems with eating and drinking. This cup only allows a total of 10 cc. at a time and so that helps prevent him from taking too many fluids at one time and prevents aspiration. I had to buy this cup again because he threw his cup and it cracked... so I couldn't hardly wait to get another one back in.I would certainly suggest you try this cup if you might have the same problems as I have. It's not inexpensive, but certainly worth not having aspiration problems.
#
#
#
#
#   I bought this cup for my 92 year old Mother at the suggestion of her speech therapist.  She used it but balked about it.  We noticed her not drinking enough which could have resulted in dehydration.  We eventually gave into her wishes and gave her another type of cup. The cup performed well.  However, the top section broke at the bottom.  After going on their web site I surmised this happens frequently since they sell that portion separately.
#
#
#
#
#   Father-in-law is at an assisted living facility and needed one. He loves it.
#
#
#
#
#   After the first use it started to leak. I have tried everything to make it not leak but it continues to leak out around the lid. I was excited for this product but disappointed in it since the first use.
#
#
#
#
#   Does exactly what it’s supposed to do.
#
#
#
#
#   The cup broke around the rim when putting the handle on. During assembly. We couldn't even use the cup because it leaks now.
#
#
#
#
#   However, the cups are large and elderly folks in assisted living facilities tend not to be able to tilt their heads back far enough to get the liquid flowing.  Expensive for plastic cup.  I bought sippy cups at Dollar Store for: . . . $1.
#
#
#
#
#   Grandma didn’t like it
#
#
#
#
#   I am not happy with this product, when my husband tries to drink it pours out to fast, if he happens to drop it, it will leak from both sides of the cup
#
#
#
#
#   I liked this product because the flow of water is much smaller
#
#
#
#
#   Do not recommend ifnyou have difficulty tilting your head back.  Otherwise it’s a great product.
#
#
#
#
#   Special cup recommended by my Dads speech pathologist. Works perfectly by delivering a tsp of water at a time to keep him from swallowing to much liquid at once
#
#
#
#
#   Greatly reduces the risk for aspiration pneumonia to the point that we have bought 3 of these cups. It can save your life or someone you love. Worth every penny.
#
#
#
#
#   Helps with dysphalgia
#
#
#
#
#   It does exactly as it is advertised to do, thus, the reason for me purchasing it.
#
#
#
#
#   Worked perfectly for my needs
#
#
#
#
#   My brother has to have this cup due to his disability causing swallowing issues.  He loves it, but the lid broke in less than two months of use-not very sturdy at all.  Disappointing :(
#
#
#
#
#   I would like a refund. this item doesnt allow enough water to get out. please contact me: anna_maestrini@yahoo.com to return
#
#
#
#
#   I ordered this for my cousin who has CP. It was recommended by his speech therapist after he had a swallow study performed. If you have a hard time tilting your head up or back then this cup is not for you. We need a cup that would only allow 10cc to enter but we found this cup is a mess for him. We are using a straw with his head tilted down. It just wasn't right for him but I like the idea and feature of it.
#
#
#
#
#   Too expensive doesn't work well
#
#
#
#
#   Handles won't stay on & it drips! Not worth the money!!
#
#
#
#
#   We purchased this cup for my father in law by request of his therapist. We received the cup and it leaks like crazy. We can’t return it because it is “ineligible for return” so now we’re stuck with a $30 paperweight.
#
#
#
#
#   Pricey but worked
#
#
#
#
#   works great for my son  now he doesn't choke when he takes a drink... would highly recommend this to anyone who has trouble swallowing.....
#
#
#
#
#   Everything is good except leaks at the seam
#
#
#
#
#   Great for keeping swallows consistent. Used it for someone with swallowing difficulty. Users must put cup down between each sip, which may be difficult for those who tire easily
#
#
#
#
#   Leaks around the edges. We have never been able to completely use 1 time due to poor fitting of mouth piece to cup. Leaked everywhere.
#
#
#
#
#   The lid cracked within a month of use. Too expensive!
#
#
#
#
#   If you're patriot loved one has dementia get them one of these before they get to sick. It really helped my Dad. Best to only use water in it but you can put other unthickened liquids into it if necessary.Worth every penny. I think everyone who gets dementia ought to be issued one of these sippy cups on the first day.
#
#
#
#
#   My father in law is 95 and to use this cup you have to tilt it at a 90 degree angle he can't do that, so it does not work for him.
#
#
#
#
#   simple devise but way to costly $36.00.  you can use a sippy cup 2.99 from walmart.
#
#
#
#
#   My dad has Parkinson's so I got this for him because of his constant aspirations. He has been getting pneumonia from aspirating after drinking. Unfortunately he won't use this cup because it looks to much like a sippy cup for a toddler. I found one that he does use which looks like a regular cup but always keeps the liquid at the lip of the cup so the head never has to tilt back to drink. I'm sure this cup works just not for my dad
#
#
#
#
#   Bought 2 both leaked badly.  Had 2 others in the past with no problems.  These are terrible
#
#
#
#
#   Poor quality, the rim of the lid cracked causing the liquid to drip on to my mother's blouse, another reason for her to dislike using it.  Despite this I will order another to try to lower her risk of choking as I think it serves its purpose
#
#
#
#
#   Great for the elderly
#
#
#
#
#   My husband is too impatient to use it, he would rather gulp and choke.
#
#
#
#
#   Does ok, but leaks a lot.
#
#
#
#
#   Does not work with thickner
#
#
#
#
#   I purchased the Provale 10cc cup for my 82 yr. old uncle who needs his liquids nectar thick. I was very disappointed in the cup. It did not work and it is not returnable because it is considered a hygiene product.  Too expensive to spend money on something that does not work, I threw the cup away.
#
#
#
#
#   Works as advertised. At least 2 or 3 times a day my mom aspirates when drinking a liquid. The provale cup now makes sure she is not getting too much liquid in her mouth at one time.
#
#
#
#
#   The only good thing about this cup is that it delivers the perfect amount of liquid which its supposed to do but the worst thing is that it leaks as its tipped up to the mouth and very expensive. For the price of this cup, it should not be leaky at all
#
#
#
#
#   Too many pieces to be used in a nursing home setting...
#
#
#
#
#   Very, very impressed with this cup! My son has not choked on liquids thanks to the cup's small amount of liquid per sip. Some what difficult to separate the parts to wash, but well worth the effort. So pleased that a speech therapist told us about this product!
#
#
#
#
#   It wasn't suitable for my brother in law condition.
#
#
#
#
#   this cup works well for controlling the amount of liquid but it will leak if the handles aren't exactly set correctly.
#
#
#
#
#   used the product foy my 90 year old mother in the past. works as it says.
#
#
#
#
#   Very hard top open especially for the elderly
#
#
#
#
#   This cup helps a lot and is worth getting. My husband chokes a lot due to a neurological disease and finds this cup helpful.
#
#
#
#
#   Bought this cup for my partner who had a massive stroke. The cup is okay for controlling the liquid intake, BUT it leaks around the seal. It's very difficult to tighten the seal, and drips coffee EVERYWHERE. As expensive as this cup is it should work like a charm. Also, I've noticed that the material its made of scratches really easy. I DO NOT own a dishwasher, I wash it with a sponge and I don't know how to explain it, but it's almost like the material is shedding, I do not believe this cup is worth the money. I wouldn't recommend it to anyone, due to the leaking and the way the cup is pealing around the lip, but it is okay for controlling intake of fluid
#
#
#
#
#   Cheep cup for the price.
#
#
#
#
#   Very helpful in preventing aspiration.
#
#
#
#
#   Keeps individual from gulping down liquids! Increases her safety during meals.
#
#
#
#
#   The lid was hard to put on and leaked. It is not as hard to take off.
#
#
#
#
#   The cup is very petite and has leakage although closed.
#
#
#
#
#   While the idea of this product is great, the execution is not. We purchased this product for my 82 year old grandmother who has difficulty swallowing, she aspirates very easily; this has caused her lungs to become infected with pneumonia. The doctor in the hospital suggested that we try this cup which we promptly ordered. Upon receiving the cup I noticed three major flaws:The cup itself is quite large and was a bit cumbersome for her (she is small and currently quite weak from the pneumonia). It was difficult even to hold it myself and help her to drink from it.In the amount of time that it took that one small teaspoon to travel from the bottom of the dosing core to the mouth she took at least four breaths. The whole point of this cup was so that she wouldn't breathe in the liquid. If she is breathing while the liquid is being poured into her mouth then that defeats the purpose.The angle at which she had to tilt her head (all the way back) to finally get the liquid into her mouth is flat out dangerous. To avoid aspiration one is supposed to tilt their chin down, NOT all the way back.While this cup may work well for certain swallowing disorders, I DO NOT recommend that you try it when attempting to avoid aspiration.
#
#
#
#
#   Completely satisfied
#
#
#
#
#   A good solution for swallow-challenged elderly.
#
#
#
#
#   My dad has been diagnosed with dysphagia & it made no difference in the drinking for him.
#
#
#
#
#   It break so easy. Don't waste your money.No star from me but I had to put this crappy star here.
#
#
#
#
#   Great product.
#
#
#
#
#   The Provale Cup was invaluable in helping my father during that most difficult time right after his mild stroke. Learning to swallow thin liquids is one of the hardest tasks after a stroke. The Provale Cup is an excellent choice to use during this time.
#
#
#
#
#   My 90 yr old mom has dysphasia. Cup works great.
#
#
#
#
#   Too hard to put together.
#
#
#
#
#   Mother had a stroke and had swallowing problems. Dr. prescribed this cup. It worked fine, but needs a little more detail with the way it seals. She had problems with leaking lid.
#
#
#
#
#   just what was needed
#
#
#
#
#   It works as stated. Controls the amount of liquid you can drink.
#
#
#
#
#   So not worth the money.  It leaks and the lid is hard to get on and off.  Handle broke within a week.
#
#
#
#
#   Cup leaks and already cracked.  Poor design for such an expense cup.
#
#
#
#
#   Great for honey thickened liquid for children with dysphagia.
#
#
#
#
#   Waste of money. Very disappointed
#
#
#
#
#   This product worked just as I expected.  Well made.
#
#
#
#
#   Too much effort for too little liquid per sip. A waste  of money.
#
#
#
#
#   Perfect. Fast shipping. Thanks.
#
#
#
#
#   Works fine.
#
#
#
#
#   This cup constantly leaks!
#
#
#
#
#   The cup is hard to use for both caregiver and patient. It is difficult for the patient to get enough liquid and cleaning it is a chore.
#
#
#
#
#   nice
#
#
#
#
#   Hard to handle
#
#
#
#
#   Good idea but did not work well for my son. It just frustrated him on not getting amount he wanted.
#
#
#
#
#   Perfect for the intended use .Great for patients with difficulty swallowing and keeping from aspiration.
#
#
#
#
#   Quality of product was good but the use of cup is not.  Alzheimer's patient could not tilt cup to drink and cup was very expensive.
#
#
#
#
#   Not sure how my cousin managed but he could still suck down more that the 5cc when he wanted to.  He is now on honey thickened liquids so we can no longer use the Provale.
#
#
#
#
#   Did not adequately regulate the flow.  Was not useful for us.
#
#
#
#
#   This cup delivered what was promised......doses out 5ml sips at a time.  The construction is solid and easy to take apart and clean.  My only complaint is that it does leak a bit when tipped up to drink.  We hold a towel under my daughter's chin anyway (because she doesn't fully swallow) so this leakage doesn't truly bother us.  I read other reviews that said the cup leaked so we were prepared.  Nevertheless, we use this cup everyday and it's great
#
#
#
#
#   Lid would not stay on. When lid is inserted into cup the long part of lid barely fits in.
#
#
#
#
#   For the price,  I  thought the quality of the cup was only average.  I put it together correctly but it still wants to leak a little.  I also thought it would be insulated, but it's not.  It has improved my mother's choking , so that is helpful.
#
#
#
#
#   This product has been a tremendous life saver in the rehabilitation of my husband, after suffering a stroke.  He can drink from this without choking.It is overpriced somewhat, but I don't think the company has any competitors.BC
#
#
#
#
#   Leaks!! Such a bummer!
#
#
#
#
#   Ok
#
#
#
#
#   Worked as advertised.
#
#
#
#
#   Bought this for my mother who had swallowing problems.  Worked as expected.
#
#
#
#
#   Great cup, great idea just did not fit our personal needs.
#
#
#
#
#   Great item!
#
#
#
#
#   It does leak which is very aggravating!!  We HAVE to use it.Waaaay over-priced!!
#
#
#
#
#   Hate it ,my husband can't use it
#
#
#
#
#   I've only used it once and it did what it was supposed to.  Still think it's pricey for a plastic cup though.
#
#
#
#
#   This item was recommended by speech therapist for a developmentally handicapped person.  He needs two of these for daily use.
#
#
#
#
#   The cup is for my mother. She inhales food and drink into her lungs and needs to drink mostly nectar thick fluids. The cup allows her to drink regular consistency fluids without inhaling it into her lungs. It only allows the person to take one small sip at a time into the mouth. It can be confusing for an older person, as they have to bring the cup down to an upright position between each sip. She did get the hang of it, although when it gets to the bottom, we have to fill it to the fill line again because she can't get the last bit out. Its good, because most people do not like the nectar thick fluids -- especially the water.
#
#
#
#
#   My husband was given a cup like this in the hospital when he was diagnosed w/ aspiration pneumonia which came from swallowing issues.  I then ordered him another so he could be drinking juice in one and water in the other.  Any other liquids he drank had to be thickened.  He has now relearned how to swallow properly so he is no longer using this cup, but it was essential for about 8 weeks.
#
#
#
#
#   Works okay for little sips but not for normal long drinks. Not for thickened liquids as noted by others.WAY TOO PRICEY... Until there is a descent knock off this cup has the monopolyWe'll see how it holds up long term
#
#
#
#
#   Great product fast delivery
#
#
#
#
#   Greatly helped to go from thickened liquids to no thickened liquids
#
#
#
#
#   As described and shipped fast
#
#
#
#
#   for the price not worth it.
#
#
#
#
#   leaks and cracks easily, not worth $35.00!!!
#
#
#
#
#   Item received on time, however, the handle comes off when in use.
#
#
#
#
#   It works well, but it is very overpriced for what it is.
#
#
#
#
#   Worked well. Shipping was fast.
#
#
#
#
#   My husband needed the 5cc cup as his swallowing problems are getting worse. I originally bought the 10cc Provale Cup. The cups work well and reduce choking.
#
#
#
#
#   works great but if not sealed just right it does leak.  the speech therapist that recommended it said that 1 in 5 of hers leaked as well, sooooo  if you get a leaky one, try to re-seat it or exchange it and hopefully you will get one that fits better
#
#
#
#
#   small cup...doesn't feel like an adult cup
#
#
#
#
#   I purchased these cups for a participant that I support that has dysphagia. She reports the cups have worked well and have met her needs to prevent choking and aspiration. They have held up with daily usage
#
#
#
#
#   Excellent quality. Easy use for a dysphasia patient. Recommend .
#
#
#
#
#   This is our second cup being used by my mother. On both cups the tab on the top has broken half off. That leaves a sharp edge. Otherwise they still work great.
#
#
#
#
#   It worked!
#
#
#
#
#   DO NOT PURCHASE THIS PRODUCT!  Terrible design:  too big/heavy, mouth piece is too thick and causes dripping after attempting to drink from it.  The cup also spills from the lid other than the spout.  Company will not allow you to return the product once it's used.  (So tell me, how would you know if it works unless you use it?)A good company would stand behind their product; this one does not.I will never purchase from this company again.
#
#
#
#
#   Helps my husband to practice his swallows after a severe stroke. I love having the technology of this cup to help him back to full health.
#
#
#
#
#   As a speech language pathologist specializing is dysphagia, I recommend this product to aid in swallowing and aspiration prevention
#
#
#
#
#   Terrible.  Did not work the way I thought it would.  My father has to keep his head straight so he will not choke.  The only way to use this cup properly is to tilt your head way back.  Not good.
#
#
#
#
#   Does not work at all with any type of thickened liquid.  It was difficult for my dad to use successfully, he was very frustrated.
#
#
#
#
#   GREAT CUP!! Our daughter's speech therapist uses one with her and she recommended we get one for home. Works well and our daughter loves her special cup.
#
#
#
#
#   Great Item that does what it says.  Changed the ease of drinking without choking  I will and I have already recommended this product..
#
#
#
#
#   Good cups and a great price!
#
#
#
#
#   The cup works well for its purpose, i.e. to control amount of fluid in one drink.  These blue 5 cc cups did not look nice after several weeks of washing by hand.  Cups that we had purchased several years ago that were the brown 10 cc cups held up much nicer.
#
#
#
#
#   Very useful with individuals I work with who are developmentally disabled. Paces drinking; thereby reducing choking risk.  Will purchase again
#
#
#
#
#   Used by mother in a nursing home and works well since she is bed ridden. Satisfied with cup. Nurses recommended cup to keep her from as operating water into her lungs.
#
#
#
#
#   Exactly what we needed.  I work in an Elementary School and we ordered this item so our parent didn't have to send it back and forth to school everyday.Thanks!
#
#
#
#
#   While the controlled amount may be frustrating for the user, it is clearly a beneficial tool for the caregiver.
#
#
#
#
#   It is working very well for me, I recommend it to others.
#
#
#
#
#   excellent cup for people with swallow difficulty/dysphagia which allows one teaspoon sized sip be taken at a time. recommend not to clean in dishwasher since cup lid does not fit well after cleaned and liquids leak out of cup.
#
#
#
#
#   That's a lot of money for plastic pored in a mold.  It does do the job. Merry Christmas and Happy New Year
#
#
#
#
#   I am a speech pathologist and regularly recommend and utilize this cup for my dysphagia patients. Recently made a realization that I think most people don't know. The cups have a front and a back. I have never ordered a brand new cup, I've only utilized existing ones, in the directions it mentions a vent. It is obvious on the lid, but very hard to see on the cup, I can only see it if I hold it up to the light, but you can feel it if you run your finger around the rim on the inside. It also helps to not fill the liquid all the way to the fill line. I have seen a few people ask about putting thickened liquids in these cups; they are for thin liquids only. Also, your loved one / patient will need decent range of motion in their neck/shoulder to utilize the cups. Hope this helps!
#
#
#
#
#   My husband used one of these in the hospital due to swallowing difficulties after radiation for tongue cancer. He was choking a lot and getting fluid in his lungs and developed aspiration pneumonia and septic shock. This worked great in the hospital and I want to get him one as he refuses to use thickners in his drinks as advised. When I can afford one I will get him one. So overpriced!
#
#
#
#
#   This cup is overpriced and needs to include cleaning directions. I have been cleaning the cup for almost three years and even with that, just found mold in the "tube" part of it.
#
#
#
#
#   buy this item if u experience any difficulty swallowing. it holds enough to keep me satisfied all night. it's easily refilable,& gives me much needed independece (i can roll my weelchair up to my disability sink,& pour water directly into the drink spout) they're pretty durable(i need a new one about every 1.5 years,but i'm not a gentle customer, if it can hang a day with me it's a bit of awesomeness)
#
#
#
#
#   One of the two purchased leaks. need a replacement.
#
#
#
#
#   This cup is the only product on the market that I am aware of- that reduces the flow administered during drinking.  I work with adults with developmental disabilities as well as adults with neuro and cognitive deficits, and this product is excellent in helping them reduce the amount of liquid that is swallowed per sip.  I find 5  cc's is desirable with most dysphagic patients who require this level of support.  It can occasionally leak, but I don't find that to be a major problem.  Sturdy design and goes through an industrial dish washer without issue.
#
#
#
#
#   Was recommended by my Fathers speech therapist. Dad had trouble swallowing after his second stroke and this helped a lot. Worth the price to help prevent choking on liquids and aspiration.Because these portions are smaller you need to take extra precautions to insure the person using the cup is getting enough daily fluid intake.Arrived on time and in great condition.
#
#
#
#
#   this cup is made of very fragile plastic....my disabled daughter accidentally dropped it after only having it 3 days....the whole top of the cup broke into pieces....just great....$35 cup that didn't last a week.....very disappointed ....they should make these out of more durable materials if they are going to sell to disabled people....accidents happen....i didn't bother with sending it back....just bought something different.....if you are going to be sitting right next to your child/adult and can be responsible for making sure it doesn't drop on the floor, it will probably work for you......but my daughter is on a self feeding program and this was supposed to help
#
#
#
#
#   This cup has really made a difference for my father. And also for me because he rarely coughs when drinking liquids an now I don't worry as much about him choking on what ever it is that he's drinking. Professional quality,Great design, Seals tight with no leaking. Its tuff an durable like Tupperware. Dad's dropped it several times an the lid never came off, but it easy to remove an put back on. I'm sure it will last an very long time.
#
#
#
#
#   This was an expensive FAILURE! I was TRYING TO FILL this EXPENSIVE CUP with water on the FIRST DAY and the handle slipped off, the cup hit the tile floor and broke! I IMMEDIATELY wrote a note to Amazon, they got right back to me and I never did hear from the company I ordered it from. It is an item I can't even return! This product was a total waste of my money and time!
#
#
#
#
#   My husband uses this cup for all of his drinks due to COPD, which was highly recommended by the speech therapist in the hospital. He loves it.
#
#
#
#
#   My mother has a difficult time trying to figure out how to use it; it's great for swallowing problems, not so great for confused Alzheimer's patients with swallowing problems. It was a lot of money; I wouldn't say I got my money's worth.
#
#
#
#
#   As a speech language pathologist specializing is dysphagia, I recommend this product to aid in swallowing and aspiration prevention
#
#
#
#
#   This helps with my husbands swallowing
#
#
#
#
#   I'm a speech therapist, and I occasionally order these for my patients. These are a great option for people that have dysphagia and either want to be independent with their liquids or cannot always be supervised. I really like these mugs, and they're more reasonably priced than RiJo.
#
#
#
#
#   Love it
#
#
#
#
#   Perfect
#
#
#
#
#   Wonderful cup, but sadly the top cap is useless with nectar thickened liquids.
#
#
#
#
#   I bought one cup as they are a little expensive.  It is for my sister who swallows too much at  one time and some goes down the wrong way.  Her doctor recommended this as a way to stop that.  It works and I will probably buy more now that we have tried it.
#
#
#
#
#   This product was exactly what I was looking for.  It is for a developmentally delay persons, so the style design is not a problem.  It works just as it should.
#
#
#
#
#   This cup helped tremendously!!!  My husband really liked using it as it allowed him to control the amount.
#
#
#
#
#   Does what it should but breaks so easily. Knocked off bedside table once, shatters mouth piece, which is bad for something so expensive, even for therapeutic products!
#
#
#
#
#   Extremely frustrating to use, 10cc is way too small for a sip. Also when the level of fluid is low, even less goes in to the dispenser part of the cup. Cant keep anybody hydrated this way. Being so expensive  we returned it.There must be a better way to help people with dysphagia.We found some children/baby cups rom Contigo (TM) with a pop-up mouth piece where the diameter of the last part of the sipping tube is much smaller. We have been training our son to take smaller sips, swallow, breathe between sips. Works most of the time, but fo the time being must keep reminding him. Should sink in over time.
#
#
#
#
#   Dispenses the perfect amount of liquid.  Found this cup preferable to thickeners.

# %%
titles = []
for soupnum in soup:
    title = soupnum.findAll("a",{'class':"a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"})
    for i in title:
        print(i.text)
# Out:
# Overpriced but works as described
#
#
# The Provale Cup dispenses 1 Tbsp of un-thickened liquid at a time and it did satisfy his thirst until he was able to heal and ...
#
#
# A truly amazing cup to assist my husband in swallowing without aspirating
#
#
# Overpriced
#
#
# Does Amazon want to keep customers?
#
#
# Safe drinking but could be better designed.
#
#
# Disappointed with the cup
#
#
# $37 FA WHATTTT???
#
#
# This cup only works if the drinker has the ability to and knows how to suck through spout
#
#
# Not worth the money
#
#
# The Perfect Solution
#
#
# Won't work with thickened beverages
#
#
# Not a solution for my husband's dysphasia
#
#
# Not worth the $ at all
#
#
# it sorta works
#
#
# Didn’t work as expected.
#
#
# Returned. Very bad design
#
#
# Product works great. We had to watch her to ensure she ...
#
#
# Dysphagia Cup
#
#
# Really like these
#
#
# Love this cup
#
#
# Pathetic excuse for a helpful device for stroke patients
#
#
# Leaks
#
#
# Measures fluid to prevent chocking
#
#
# Works good at delivering a small amount of liquid
#
#
# This cup is WONDERFUL! My son has a tracheotomy and he has ...
#
#
# I bought this cup for my 92 year old Mother ...
#
#
# Great cup for people that need this
#
#
# Leaking :(
#
#
# Helps prevent choking from taking gulps
#
#
# Broken cup.. Without even using it.
#
#
# Fluid flow is Right
#
#
# ✅
#
#
# will not seal i
#
#
# Cup
#
#
# Recommend for certain individuals
#
#
# Perfect for dysphagia
#
#
# Worth every penny to prevent aspiration pneumonia.
#
#
# Dad lOves it
#
#
# For those who want a little sip
#
#
# Great cup
#
#
# Lid broke after less than 2 months
#
#
# Terrible Cup
#
#
# It was recommended by his speech therapist after he had a swallow ...
#
#
# cup
#
#
# Not made very good
#
#
# There are better and cheaper options.
#
#
# Pricey
#
#
# throat problems
#
#
# special cup
#
#
# Great product - Provale cup
#
#
# Leaks all over you
#
#
# Cracked lid
#
#
# If you're patriot loved one has dementia get them one of these before ...
#
#
# Must be as able to tilt cup to 90 degrees to work
#
#
# expensive
#
#
# Can't use
#
#
# very bad both leaking
#
#
# Poor quality, the rim of the lid cracked causing ...
#
#
# Perfect
#
#
# You need to be patient
#
#
# Three Stars
#
#
# Four Stars
#
#
# I was very disappointed in the cup
#
#
# Works as advertised
#
#
# The only good thing about this cup is that it delivers the ...
#
#
# Need no moving parts
#
#
# Effective product
#
#
# Good idea
#
#
# good cup overall
#
#
# used in the past
#
#
# Opening up the item
#
#
# Provale Cup to aid swallowing
#
#
# Not worth the money
#
#
# Wast of money.
#
#
# Five Stars
#
#
# Just a sip at a time!
#
#
# One Star
#
#
# One Star
#
#
# DO NOT USE if you are worried about aspiration.
#
#
# Very helpful for my father in law
#
#
# Four Stars
#
#
# Two Stars
#
#
# It break so easy. Don't waste your money
#
#
# Cup
#
#
# Excellent choice for stroke victims.
#
#
# It works
#
#
# One Star
#
#
# It worked fine, but needs a little more detail with the ...
#
#
# Four Stars
#
#
# Four Stars
#
#
# So not worth the money. It leaks and the ...
#
#
# Poor design for such an expense cup
#
#
# Useful cup
#
#
# One Star
#
#
# Five Stars
#
#
# A waste of money
#
#
# Five Stars
#
#
# Works as expected..
#
#
# One Star
#
#
# The cup is hard to use for both caregiver and ...
#
#
# Five Stars
#
#
# Three Stars
#
#
# Good idea
#
#
# Great cup
#
#
# Quality of product was good but the use of cup is not
#
#
# Provale cup 5 cc.
#
#
# Still too much
#
#
# We use this cup everyday
#
#
# Lid doesn't fit well.
#
#
# Quality of Cup
#
#
# Great product!
#
#
# Leaks
#
#
# Five Stars
#
#
# Good product
#
#
# Five Stars
#
#
# Two Stars
#
#
# Five Stars
#
#
# Four Stars
#
#
# Hate it, my husband can't use
#
#
# Pricey but works
#
#
# provale cup
#
#
# This cup is worth buying for people with swallowing problems
#
#
# Necessity for swallowing issues
#
#
# Works as indicated
#
#
# Five Stars
#
#
# Provable cups
#
#
# Five Stars
#
#
# Two Stars
#
#
# Three Stars
#
#
# Three Stars
#
#
# Three Stars
#
#
# Five Stars
#
#
# Provale Cup
#
#
# works great but if not sealed just right it does leak
#
#
# doesn't feel like an adult
#
#
# I purchased these cups for a participant that I support ...
#
#
# Excellent product
#
#
# Works as advertised with minor issue.
#
#
# Four Stars
#
#
# Terrible product
#
#
# I love having the technology of this cup to help him ...
#
#
# I recommend this product to aid in swallowing and aspiration
#
#
# Provale Cup 5cc
#
#
# Does not work at all with any type of thickened ...
#
#
# GREAT CUP!
#
#
# Swallow not choke
#
#
# Five Stars
#
#
# These blue 5 cc cups did not look nice after several weeks of washing by hand
#
#
# product as described
#
#
# Asperating
#
#
# Perfect!!
#
#
# Five Stars
#
#
# I recommend it to others
#
#
# cup to use when only small sips are to be taken to help improve swallowing ; cup only works with regular thin liquids
#
#
# Price
#
#
# Is your cup leaking? They have a front and a back!
#
#
# This works
#
#
# This cup is overpriced and needs to include cleaning directions ...
#
#
# awesome, buy now
#
#
# The most important thing should be quality and guarantee.
#
#
# Excellent for adults with dysphagia
#
#
# Was recommended by my Fathers speech therapist
#
#
# just great..
#
#
# Well worth the price for peace of mind.
#
#
# SAVE YOUR MONEY-DON'T BUY THIS!
#
#
# A great drinking utensil
#
#
# it's great for swallowing problems
#
#
# I recommend this product to aid in swallowing and aspiration
#
#
# Good health
#
#
# These are a great option for people that have dysphagia and either want ...
#
#
# Na
#
#
# Perfect
#
#
# Four Stars
#
#
# Her doctor recommended this as a way to stop that
#
#
# This product was exactly what I was looking for. ...
#
#
# Works very well
#
#
# Works but plastic breaks very easily.
#
#
# There must be a better way to help people with dysphagia
#
#
# Five Stars

# %%
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
HEADERS = {
    'authority': 'fls-na.amazon.com',
'method' : 'GET',
'path' : '/1/batch/1/OP/ATVPDKIKX0DER:139-0997389-0276609:NQWXHVBY6MCGZ6ZFM91Q$uedata=s:%2Frd%2Fuedata%3Fat%26v%3D0.215337.0%26id%3DNQWXHVBY6MCGZ6ZFM91Q%26ctb%3D1%26m%3D1%26sc%3DNQWXHVBY6MCGZ6ZFM91Q%26pc%3D1452%26at%3D1452%26t%3D1612360136843%26pty%3DCustomerReviews%26spty%3DremoteProduct%26pti%3DB000NKGGGO%26tid%3DHPZXB0930WXTM9QYEJQV%26aftb%3D1%26ui%3D2:1453',
'scheme' : 'https',
'accept':'*/*',
'user-agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.104 Safari/537.36'
    
}
 
    # The webpage URL
URL = "https://www.amazon.com/PROVALE-Regulating-Drinking-Cup-5cc/dp/B000NKGGGO/"
 
    # HTTP Request
webpage = requests.get(URL, headers=HEADERS)
 
    # Soup Object containing all data
soup = BeautifulSoup(webpage.content, "lxml")
print("Product Rating =", get_rating(soup))
print("Number of Product Reviews =", get_review_count(soup))
# Out:
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 398 ratings
